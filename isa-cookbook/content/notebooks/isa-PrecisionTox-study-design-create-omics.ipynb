# %% [markdown]
# # ISA Create Mode example

# %% [markdown]
# ## Abstract:
#
# In this notebook, we'll show how to generate an ISA-Tab and an ISA JSON representation of a metabolomics study.
# The study uses GC-MS and 13C NMR on 3 distinct sample types (liver, blood and heart) collected from study subjects assigned to 3 distinct study arms.
#
# GC-MS acquisition were carried out in duplicate, extracts were derivatized using BSA and acquired on an Agilent QTOF in both positive and negative modes.
# 13C NMR free induction decays were acquired on a Bruker Avance, using CPMG and PSEQ pulse sequences in duplicates.

# %% [markdown]
# ### 1. Loading ISA-API model and relevant library

# %%
# If executing the notebooks on `Google Colab`,uncomment the following command 
# and run it to install the required python libraries. Also, make the test datasets available.

# !pip install -r requirements.txt

# %%
from isatools import isatab
from isatools.isajson import ISAJSONEncoder
from collections import OrderedDict
from isatools.model import (
    Investigation,
    OntologySource,
    OntologyAnnotation,
    FactorValue,
    Characteristic
)
from isatools.create.model import (
    Treatment,
    NonTreatment,
    StudyCell,
    StudyArm,
    ProductNode,
    SampleAndAssayPlan,
    StudyDesign,
    QualityControl
)
from isatools.create.constants import (
    BASE_FACTORS,
    SCREEN,
    RUN_IN,
    WASHOUT,
    FOLLOW_UP,
    SAMPLE,
    EXTRACT,
    LABELED_EXTRACT,
    DATA_FILE
)
from isatools.isatab import dump_tables_to_dataframes as dumpdf
import os
import json

# %% [markdown]
# ### 2. Setting variables:

# %%
# ontologies
ontologies = {
    "chebi": OntologySource(
        name = "CHEBI",
        description = "Chemical Entities of Biological Interest"),
    "chmo": OntologySource(
        name = "CHMO", 
        description = "Chemical Methods Ontology"),
    "msio": OntologySource(
        name = "MSIO",
        description = "Metabolite Standards Initiative Ontology"),
    "ncbitaxon": OntologySource(
        name = "NCBITAXON", 
        description = "NCBI organismal classification"),
    "ncit": OntologySource(
        name = "NCIT", 
        description = "NCI Thesaurus OBO Edition"),
    "obi": OntologySource(
        name = "OBI", 
        description = "Ontology for Biomedical Investigations"),
    "uo": OntologySource(
        name = "UO", 
        description = "UO - the Unit Ontology"),
    "pato": OntologySource(
        name = "PATO", 
        description = "PATO - the Phenotype And Trait Ontology"),
    "uberon": OntologySource(
        name = "UBERON", 
        description = "Uber-anatomy ontology")
}
# add ontologies to investigation

isa_investigation = Investigation()

for o in ontologies.values():
    isa_investigation.ontology_source_references.append(o)


NAME = 'name'
FACTORS_0_VALUE = OntologyAnnotation(term='cadmium chloride') #, term_accession='http://purl.obolibrary.org/obo/CHEBI_35456', term_source='CHEBI'
FACTORS_0_VALUE_ALT = OntologyAnnotation(term='ethoprophos') #, term_accession='http://purl.obolibrary.org/obo/CHEBI_38665', term_source='CHEBI'
FACTORS_0_VALUE_THIRD = OntologyAnnotation(term='pirinixic acid') #, term_accession='http://purl.obolibrary.org/obo/CHEBI_32509', term_source='CHEBI'

FACTORS_1_VALUE = 5
FACTORS_2_VALUE_ALT = "BMD"
FACTORS_2_VALUE_THIRD = "EC25"
FACTORS_1_UNIT = OntologyAnnotation(term='kg/m^3') # , term_accession='http://purl.obolibrary.org/obo/UO_0000083', term_source='UO'

FACTORS_2_VALUE = 0
FACTORS_2_VALUE_ALT = 4
FACTORS_2_VALUE_2 = 24
FACTORS_2_VALUE_3 = 48
FACTORS_2_UNIT = OntologyAnnotation(term='hr')

TEST_EPOCH_0_NAME = 'test epoch 0'
TEST_EPOCH_1_NAME = 'test epoch 1'
TEST_EPOCH_2_NAME = 'test epoch 2'

TEST_STUDY_ARM_NAME_00 = 'test arm'
TEST_STUDY_ARM_NAME_01 = 'another arm'
TEST_STUDY_ARM_NAME_02 = 'yet another arm'

TEST_STUDY_DESIGN_NAME = 'test study design'

TEST_EPOCH_0_RANK = 0

SCREEN_DURATION_VALUE = 100
FOLLOW_UP_DURATION_VALUE = 5*366
WASHOUT_DURATION_VALUE = 30
DURATION_UNIT = OntologyAnnotation(term='day') #, term_accession='http://purl.obolibrary.org/obo/UO_0000033', term_source='UO'

# %% [markdown]
# ### 3. Declaration of ISA Sample / Biomaterial templates for liver, blood and heart

# %%
sample_list = [
        {
            'node_type': SAMPLE,
            'characteristics_category': OntologyAnnotation(term='organism part'),
            'characteristics_value': OntologyAnnotation(term='whole organism'), # term_accession='http://purl.obolibrary.org/obo/OBI_0100026', term_source='OBI'
            'size': 1,
            'technical_replicates': None,
            'is_input_to_next_protocols': True
        }
]

# %% [markdown]
# ### 4. Declaration of ISA Assay templates as Python `OrderedDict`

# %%
# A Mass Spectrometry based metabolite profiling assay

ms_assay_dict = OrderedDict([
    ('measurement_type', OntologyAnnotation(term='metabolite profiling')),
    ('technology_type', OntologyAnnotation(term='mass spectrometry')),
    ('extraction', {}),
    ('extract', [
        {
            'node_type': EXTRACT,
            'characteristics_category': OntologyAnnotation(term='extract type'),
            'characteristics_value': OntologyAnnotation(term='polar fraction'),
            'size': 1,
            'is_input_to_next_protocols': True
        },
        {
            'node_type': EXTRACT,
            'characteristics_category': OntologyAnnotation(term='extract type'),
            'characteristics_value': OntologyAnnotation(term='lipids'),
            'size': 1,
            'is_input_to_next_protocols': True
        }
    ]),
    ('derivatization', {
        '#replicates': 1,
        OntologyAnnotation(term='derivatization'): ['sylalation'],
        OntologyAnnotation(term='derivatization'): ['bis(trimethylsilyl)acetamide'],
    }),
    ('labeled extract', [
        {
            'node_type': LABELED_EXTRACT,
            'characteristics_category': OntologyAnnotation(term='labeled extract type'),
            'characteristics_value': '',
            'size': 1,
            'is_input_to_next_protocols': True
        }
    ]),
    ('mass spectrometry', {
        '#replicates': 2,
        OntologyAnnotation(term='instrument'): ['Agilent QTOF'],
        OntologyAnnotation(term='injection_mode'): ['GC'],
        OntologyAnnotation(term='acquisition_mode'): ['positive mode','negative mode']
    }),
    ('raw spectral data file', [
        {
            'node_type': DATA_FILE,
            'size': 1,
            'is_input_to_next_protocols': False
        }
    ])
])


# A high-throughput phenotyping imaging based phenotyping assay

phti_assay_dict = OrderedDict([
    ('measurement_type', OntologyAnnotation(term='phenotyping')),
    ('technology_type', OntologyAnnotation(term='high-throughput imaging')),
            ('extraction', {}),
            ('extract', [
                {
                    'node_type': EXTRACT,
                    'characteristics_category': OntologyAnnotation(term='extract type'),
                    'characteristics_value': OntologyAnnotation(term='supernatant'),
                    'size': 1,
                    'technical_replicates': None,
                    'is_input_to_next_protocols': True
                }
            ]),
            ('phenotyping by high throughput imaging', {
                'OntologyAnnotation(term=instrument)': ['lemnatech gigant'],
                'OntologyAnnotation(term=acquisition_mode)': ['UV light','near-IR light','far-IR light','visible light'],
                'OntologyAnnotation(term=camera position)': ['top','120 degree','240 degree','360 degree'],
                'OntologyAnnotation(term=imaging daily schedule)': ['06.00','19.00']
            }),
            ('raw_spectral_data_file', [
                {
                    'node_type': DATA_FILE,
                    'size': 1,
                    'technical_replicates': 2,
                    'is_input_to_next_protocols': False
                }
            ])
        ])

# A RNA-Seq based transcription profiling assay

rnaseq_assay_dict = OrderedDict([
    ('measurement_type', OntologyAnnotation(term='transcription profiling')), # term_source="OBI", term_accession="http://purl.obolibrary.org/obo/OBI_000066"
    ('technology_type', OntologyAnnotation(term='nucleotide sequencing')), #, term_source="OBI", term_accession="http://purl.obolibrary.org/obo/OBI_0000234"
            ('extraction', {}),
            ('extract', [
                {
                    'node_type': EXTRACT,
                    'characteristics_category': OntologyAnnotation(term='extract type'),
                    'characteristics_value': OntologyAnnotation(term='mRNA'),
                    'size': 1,
                    'technical_replicates': None,
                    'is_input_to_next_protocols': True
                }
            ]),
            ('library_preparation', {
                'OntologyAnnotation(term=library strategy)': ['RNA-SEQ'],
                'OntologyAnnotation(term=library layout)': ['PAIRED'],
                'OntologyAnnotation(term=size)': ['40'],
            }),
            ('nucleic acid sequencing', {
                'OntologyAnnotation(term=sequencing instrument)': ['DNBSEQ-T7']
            }),
            ('raw_data_file', [
                {
                    'node_type': DATA_FILE,
                    'size': 1,
                    'technical_replicates': 1,
                    'is_input_to_next_protocols': False
                }
            ])
        ])

# %% [markdown]
# ### 5. Declaring Study Design key elements in terms of Treatments and Non-Treatment elements, Study Cell & Arms

# %%
first_treatment = Treatment(factor_values=(
    FactorValue(factor_name=BASE_FACTORS[0], value=FACTORS_0_VALUE),
    FactorValue(factor_name=BASE_FACTORS[1], value=FACTORS_1_VALUE, unit=FACTORS_1_UNIT),
    FactorValue(factor_name=BASE_FACTORS[2], value=FACTORS_2_VALUE, unit=FACTORS_2_UNIT)
))
second_treatment = Treatment(factor_values=(
    FactorValue(factor_name=BASE_FACTORS[0], value=FACTORS_0_VALUE_ALT),
    FactorValue(factor_name=BASE_FACTORS[1], value=FACTORS_1_VALUE, unit=FACTORS_1_UNIT),
    FactorValue(factor_name=BASE_FACTORS[2], value=FACTORS_2_VALUE, unit=FACTORS_2_UNIT)
))
third_treatment = Treatment(factor_values=(
    FactorValue(factor_name=BASE_FACTORS[0], value=FACTORS_0_VALUE_ALT),
    FactorValue(factor_name=BASE_FACTORS[1], value=FACTORS_1_VALUE, unit=FACTORS_1_UNIT),
    FactorValue(factor_name=BASE_FACTORS[2], value=FACTORS_2_VALUE_ALT, unit=FACTORS_2_UNIT)
))
fourth_treatment = Treatment(factor_values=(
    FactorValue(factor_name=BASE_FACTORS[0], value=FACTORS_0_VALUE_THIRD),
    FactorValue(factor_name=BASE_FACTORS[1], value=FACTORS_1_VALUE, unit=FACTORS_1_UNIT),
    FactorValue(factor_name=BASE_FACTORS[2], value=FACTORS_2_VALUE, unit=FACTORS_2_UNIT)
))

#screen = NonTreatment(element_type=SCREEN, duration_value=SCREEN_DURATION_VALUE, duration_unit=DURATION_UNIT)
#run_in = NonTreatment(element_type=RUN_IN, duration_value=WASHOUT_DURATION_VALUE, duration_unit=DURATION_UNIT)
#washout = NonTreatment(element_type=WASHOUT, duration_value=WASHOUT_DURATION_VALUE, duration_unit=DURATION_UNIT)
#follow_up = NonTreatment(element_type=FOLLOW_UP, duration_value=FOLLOW_UP_DURATION_VALUE, duration_unit=DURATION_UNIT)
#potential_concomitant_washout = NonTreatment(element_type=WASHOUT, duration_value=FACTORS_2_VALUE,
#                                                          duration_unit=FACTORS_2_UNIT)
#cell_screen = StudyCell(SCREEN, elements=(screen,))
#cell_run_in = StudyCell(RUN_IN, elements=(run_in,))
#cell_other_run_in = StudyCell('OTHER RUN-IN', elements=(run_in,))
#cell_screen_and_run_in = StudyCell('SCREEN AND RUN-IN', elements=[screen, run_in])
#cell_concomitant_treatments = StudyCell('CONCOMITANT TREATMENTS',
#                                                     elements=([{second_treatment, fourth_treatment}]))
#cell_washout_00 = StudyCell(WASHOUT, elements=(washout,))
#cell_washout_01 = StudyCell('ANOTHER WASHOUT', elements=(washout,))
cell_single_treatment_00 = StudyCell('SINGLE TREATMENT FIRST', elements=[first_treatment])
cell_single_treatment_01 = StudyCell('SINGLE TREATMENT SECOND', elements=[second_treatment])
cell_single_treatment_02 = StudyCell('SINGLE TREATMENT THIRD', elements=[third_treatment])
#cell_multi_elements = StudyCell('MULTI ELEMENTS',
#                                             elements=[{first_treatment, second_treatment,
#                                                        fourth_treatment}, washout, second_treatment])
#cell_multi_elements_padded = StudyCell('MULTI ELEMENTS PADDED',
#                                                    elements=[first_treatment, washout, {
#                                                        second_treatment,
#                                                        fourth_treatment
#                                                    }, washout, third_treatment, washout])
#cell_follow_up = StudyCell(FOLLOW_UP, elements=(follow_up,))
#cell_follow_up_01 = StudyCell('ANOTHER FOLLOW_UP', elements=(follow_up,))
#qc = QualityControl()

ms_sample_assay_plan = SampleAndAssayPlan.from_sample_and_assay_plan_dict("ms_sap", sample_list, ms_assay_dict)
rnaseq_sample_assay_plan = SampleAndAssayPlan.from_sample_and_assay_plan_dict("rnaseq_sap", sample_list, rnaseq_assay_dict)
phti_sample_assay_plan = SampleAndAssayPlan.from_sample_and_assay_plan_dict("phti_sap", sample_list, phti_assay_dict)



first_arm = StudyArm(name=TEST_STUDY_ARM_NAME_00, group_size=3, arm_map=OrderedDict([
  #  (cell_screen, None), (cell_run_in, None),
    (cell_single_treatment_00, ms_sample_assay_plan),
     (cell_single_treatment_00, rnaseq_sample_assay_plan)
   # (cell_follow_up, ms_sample_assay_plan)
]))
second_arm = StudyArm(name=TEST_STUDY_ARM_NAME_01, group_size=3, arm_map=OrderedDict([
   # (cell_screen, None), (cell_run_in, None),
    (cell_single_treatment_01, ms_sample_assay_plan),
    (cell_single_treatment_01, rnaseq_sample_assay_plan)
    #(cell_multi_elements, ms_sample_assay_plan),
   # (cell_follow_up, ms_sample_assay_plan)
]))
third_arm = StudyArm(name=TEST_STUDY_ARM_NAME_02, group_size=3, arm_map=OrderedDict([
   # (cell_screen, None), (cell_run_in, None),
    (cell_single_treatment_02,rnaseq_sample_assay_plan),
    (cell_single_treatment_02, ms_sample_assay_plan)

   # (cell_multi_elements_padded, ms_sample_assay_plan),
   # (cell_follow_up, ms_sample_assay_plan)
]))
#third_arm_no_run_in = StudyArm(name=TEST_STUDY_ARM_NAME_02, group_size=3, arm_map=OrderedDict([
   # (cell_screen, None),
 #   (cell_multi_elements_padded, ms_sample_assay_plan),
   # (cell_follow_up, ms_sample_assay_plan)
#]))
#arm_same_name_as_third = StudyArm(name=TEST_STUDY_ARM_NAME_02, group_size=3, arm_map=OrderedDict([
    #(cell_screen, None), (cell_run_in, None),
#    (cell_single_treatment_01, ms_sample_assay_plan),
    #(cell_follow_up, ms_sample_assay_plan)
#]))


# Sample QC (for mass spectroscopy and other)
#pre_run_sample_type = ProductNode(
#    id_='pre/00', node_type=SAMPLE, name='water', size=2, characteristics=(
#        Characteristic(category='dilution', value=10, unit='mg/L'),
#    )
#)
#post_run_sample_type = ProductNode(
#    id_='post/00', node_type=SAMPLE, name='ethanol', size=2, characteristics=(
#        Characteristic(category='dilution', value=1000, unit='mg/L'),
#        Characteristic(category='dilution', value=100, unit='mg/L'),
#        Characteristic(category='dilution', value=10, unit='mg/L'),
#        Characteristic(category='dilution', value=1, unit='mg/L'),
#        Characteristic(category='dilution', value=0.1, unit='mg/L')
#    ))
#dummy_sample_type = ProductNode(id_='dummy/01', node_type=SAMPLE, name='dummy')
#more_dummy_sample_type = ProductNode(id_='dummy/02', node_type=SAMPLE, name='more dummy')
#interspersed_sample_types = [(dummy_sample_type, 20)]

#qc = QualityControl(
#    interspersed_sample_type=interspersed_sample_types,
#    pre_run_sample_type=pre_run_sample_type,
#    post_run_sample_type=post_run_sample_type
#)

# %%
# single_arm = StudyArm(name=TEST_STUDY_ARM_NAME_00, group_size=10, arm_map=OrderedDict([
#    # (cell_screen, ms_sample_assay_plan), (cell_run_in,ms_sample_assay_plan),
#     (cell_single_treatment_00, rnaseq_sample_assay_plan),
#    # (cell_follow_up, rnaseq_sample_assay_plan)
# ]))
study_design = StudyDesign(study_arms=(first_arm, second_arm, third_arm))

# %% [markdown]
# ### 6. Generated ISA Study from ISA Study Design Object

# %%
study = study_design.generate_isa_study()

# %%
study
# Out:
# isatools.model.Study(filename='s_study_01.txt', identifier='s_01', title='Study Design', description='None', submission_date='', public_release_date='', contacts=[], design_descriptors=[], publications=[], factors=[isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), isatools.model.StudyFactor(name='Sequence Order', factor_type=isatools.model.OntologyAnnotation(term='sequence order', term_source=None, term_accession='', comments=[]), comments=[])], protocols=[isatools.model.Protocol(name='sample collection', protocol_type=isatools.model.OntologyAnnotation(term='sample_collection', term_source=None, term_accession='', comments=[]), uri='', version='', parameters=[isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='Sampling order', term_source=None, term_accession='', comments=[]), comments=[]), isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='Study cell', term_source=None, term_accession='', comments=[]), comments=[])], components=[], comments=[]), isatools.create.model.ProtocolNode(id=extraction_000, name=assay0 - extraction, protocol_type=OntologyAnnotation(
#     term=assay0 - extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.model.ProtocolNode(id=mass_spectrometry_001_000, name=assay0 - mass spectrometry, protocol_type=OntologyAnnotation(
#     term=assay0 - mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTOF', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='GC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='negative mode', unit=None, comments=[])]), isatools.create.model.ProtocolNode(id=library_preparation_000_000, name=assay0 - library_preparation, protocol_type=OntologyAnnotation(
#     term=assay0 - library_preparation
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library strategy)', term_source=None, term_accession='', comments=[]), comments=[]), value='RNA-SEQ', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library layout)', term_source=None, term_accession='', comments=[]), comments=[]), value='PAIRED', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=size)', term_source=None, term_accession='', comments=[]), comments=[]), value='40', unit=None, comments=[])]), isatools.create.model.ProtocolNode(id=derivatization_000_001, name=assay0 - derivatization, protocol_type=OntologyAnnotation(
#     term=assay0 - derivatization
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='derivatization', term_source=None, term_accession='', comments=[]), comments=[]), value='bis(trimethylsilyl)acetamide', unit=None, comments=[])]), isatools.create.model.ProtocolNode(id=derivatization_000_000, name=assay0 - derivatization, protocol_type=OntologyAnnotation(
#     term=assay0 - derivatization
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='derivatization', term_source=None, term_accession='', comments=[]), comments=[]), value='bis(trimethylsilyl)acetamide', unit=None, comments=[])]), isatools.create.model.ProtocolNode(id=nucleic_acid_sequencing_000_000, name=assay0 - nucleic acid sequencing, protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=sequencing instrument)', term_source=None, term_accession='', comments=[]), comments=[]), value='DNBSEQ-T7', unit=None, comments=[])]), isatools.create.model.ProtocolNode(id=mass_spectrometry_000_001, name=assay0 - mass spectrometry, protocol_type=OntologyAnnotation(
#     term=assay0 - mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTOF', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='GC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='positive mode', unit=None, comments=[])]), isatools.create.model.ProtocolNode(id=mass_spectrometry_001_001, name=assay0 - mass spectrometry, protocol_type=OntologyAnnotation(
#     term=assay0 - mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTOF', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='GC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='negative mode', unit=None, comments=[])]), isatools.create.model.ProtocolNode(id=mass_spectrometry_000_000, name=assay0 - mass spectrometry, protocol_type=OntologyAnnotation(
#     term=assay0 - mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTOF', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='GC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='positive mode', unit=None, comments=[])])], assays=[isatools.model.Assay(measurement_type=isatools.model.OntologyAnnotation(term='transcription profiling', term_source=None, term_accession='', comments=[]), technology_type=isatools.model.OntologyAnnotation(term='nucleotide sequencing', term_source=None, term_accession='', comments=[]), technology_platform='', filename='a_AT0_transcription-profiling_nucleotide-sequencing.txt', data_files=[isatools.model.RawDataFile(filename='AT0-S1-raw_data_file-R1-', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='AT0-S2-raw_data_file-R1-', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='AT0-S3-raw_data_file-R1-', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='AT0-S4-raw_data_file-R1-', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='AT0-S5-raw_data_file-R1-', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='AT0-S6-raw_data_file-R1-', generated_from=[], comments=[])], samples=[], process_sequence=[isatools.model.Process(id="". name="AT0-S1-assay0---extraction-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=extraction_000,
#         name=assay0 - extraction,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[])
#         , date="None", performer="Unknown", inputs=[isatools.model.Sample(name='GRP1_SBJ2_SINGLE-TREATMENT-SECOND_SMP-whole-organism-1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='whole organism', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='Sequence Order', factor_type=isatools.model.OntologyAnnotation(term='sequence order', term_source=None, term_accession='', comments=[]), comments=[]), value=0, unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit=isatools.model.OntologyAnnotation(term='kg/m^3', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='ethoprophos', term_source=None, term_accession='', comments=[]), unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=100.0, unit=isatools.model.OntologyAnnotation(term='s', term_source=None, term_accession='', comments=[]))], derives_from=[isatools.model.Source(name='GRP1_SBJ2', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[isatools.model.Comment(name='study step with treatment', value='YES')])], outputs=[isatools.model.Extract(name='AT0-S1-Extract-R1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='mRNA', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])]), isatools.model.Process(id="". name="AT0-S1-assay0---library_preparation-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=library_preparation_000_000,
#         name=assay0 - library_preparation,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - library_preparation
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library strategy)', term_source=None, term_accession='', comments=[]), comments=[]), value='RNA-SEQ', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library layout)', term_source=None, term_accession='', comments=[]), comments=[]), value='PAIRED', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=size)', term_source=None, term_accession='', comments=[]), comments=[]), value='40', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[isatools.model.Extract(name='AT0-S1-Extract-R1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='mRNA', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Process(id="". name="AT0-S1-assay0---nucleic-acid-sequencing-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=nucleic_acid_sequencing_000_000,
#         name=assay0 - nucleic acid sequencing,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=sequencing instrument)', term_source=None, term_accession='', comments=[]), comments=[]), value='DNBSEQ-T7', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[], outputs=[isatools.model.RawDataFile(filename='AT0-S1-raw_data_file-R1-', generated_from=[], comments=[])])]), isatools.model.Process(id="". name="AT0-S1-assay0---nucleic-acid-sequencing-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=nucleic_acid_sequencing_000_000,
#         name=assay0 - nucleic acid sequencing,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=sequencing instrument)', term_source=None, term_accession='', comments=[]), comments=[]), value='DNBSEQ-T7', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[], outputs=[isatools.model.RawDataFile(filename='AT0-S1-raw_data_file-R1-', generated_from=[], comments=[])]), isatools.model.Process(id="". name="AT0-S2-assay0---extraction-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=extraction_000,
#         name=assay0 - extraction,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[])
#         , date="None", performer="Unknown", inputs=[isatools.model.Sample(name='GRP1_SBJ3_SINGLE-TREATMENT-SECOND_SMP-whole-organism-1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='whole organism', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='Sequence Order', factor_type=isatools.model.OntologyAnnotation(term='sequence order', term_source=None, term_accession='', comments=[]), comments=[]), value=0, unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit=isatools.model.OntologyAnnotation(term='kg/m^3', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='ethoprophos', term_source=None, term_accession='', comments=[]), unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=100.0, unit=isatools.model.OntologyAnnotation(term='s', term_source=None, term_accession='', comments=[]))], derives_from=[isatools.model.Source(name='GRP1_SBJ3', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[isatools.model.Comment(name='study step with treatment', value='YES')])], outputs=[isatools.model.Extract(name='AT0-S2-Extract-R1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='mRNA', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])]), isatools.model.Process(id="". name="AT0-S2-assay0---library_preparation-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=library_preparation_000_000,
#         name=assay0 - library_preparation,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - library_preparation
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library strategy)', term_source=None, term_accession='', comments=[]), comments=[]), value='RNA-SEQ', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library layout)', term_source=None, term_accession='', comments=[]), comments=[]), value='PAIRED', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=size)', term_source=None, term_accession='', comments=[]), comments=[]), value='40', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[isatools.model.Extract(name='AT0-S2-Extract-R1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='mRNA', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Process(id="". name="AT0-S2-assay0---nucleic-acid-sequencing-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=nucleic_acid_sequencing_000_000,
#         name=assay0 - nucleic acid sequencing,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=sequencing instrument)', term_source=None, term_accession='', comments=[]), comments=[]), value='DNBSEQ-T7', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[], outputs=[isatools.model.RawDataFile(filename='AT0-S2-raw_data_file-R1-', generated_from=[], comments=[])])]), isatools.model.Process(id="". name="AT0-S2-assay0---nucleic-acid-sequencing-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=nucleic_acid_sequencing_000_000,
#         name=assay0 - nucleic acid sequencing,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=sequencing instrument)', term_source=None, term_accession='', comments=[]), comments=[]), value='DNBSEQ-T7', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[], outputs=[isatools.model.RawDataFile(filename='AT0-S2-raw_data_file-R1-', generated_from=[], comments=[])]), isatools.model.Process(id="". name="AT0-S3-assay0---extraction-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=extraction_000,
#         name=assay0 - extraction,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[])
#         , date="None", performer="Unknown", inputs=[isatools.model.Sample(name='GRP1_SBJ1_SINGLE-TREATMENT-SECOND_SMP-whole-organism-1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='whole organism', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='Sequence Order', factor_type=isatools.model.OntologyAnnotation(term='sequence order', term_source=None, term_accession='', comments=[]), comments=[]), value=0, unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit=isatools.model.OntologyAnnotation(term='kg/m^3', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='ethoprophos', term_source=None, term_accession='', comments=[]), unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=100.0, unit=isatools.model.OntologyAnnotation(term='s', term_source=None, term_accession='', comments=[]))], derives_from=[isatools.model.Source(name='GRP1_SBJ1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[isatools.model.Comment(name='study step with treatment', value='YES')])], outputs=[isatools.model.Extract(name='AT0-S3-Extract-R1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='mRNA', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])]), isatools.model.Process(id="". name="AT0-S3-assay0---library_preparation-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=library_preparation_000_000,
#         name=assay0 - library_preparation,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - library_preparation
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library strategy)', term_source=None, term_accession='', comments=[]), comments=[]), value='RNA-SEQ', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library layout)', term_source=None, term_accession='', comments=[]), comments=[]), value='PAIRED', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=size)', term_source=None, term_accession='', comments=[]), comments=[]), value='40', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[isatools.model.Extract(name='AT0-S3-Extract-R1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='mRNA', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Process(id="". name="AT0-S3-assay0---nucleic-acid-sequencing-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=nucleic_acid_sequencing_000_000,
#         name=assay0 - nucleic acid sequencing,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=sequencing instrument)', term_source=None, term_accession='', comments=[]), comments=[]), value='DNBSEQ-T7', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[], outputs=[isatools.model.RawDataFile(filename='AT0-S3-raw_data_file-R1-', generated_from=[], comments=[])])]), isatools.model.Process(id="". name="AT0-S3-assay0---nucleic-acid-sequencing-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=nucleic_acid_sequencing_000_000,
#         name=assay0 - nucleic acid sequencing,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=sequencing instrument)', term_source=None, term_accession='', comments=[]), comments=[]), value='DNBSEQ-T7', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[], outputs=[isatools.model.RawDataFile(filename='AT0-S3-raw_data_file-R1-', generated_from=[], comments=[])]), isatools.model.Process(id="". name="AT0-S4-assay0---extraction-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=extraction_000,
#         name=assay0 - extraction,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[])
#         , date="None", performer="Unknown", inputs=[isatools.model.Sample(name='GRP2_SBJ2_SINGLE-TREATMENT-FIRST_SMP-whole-organism-1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='whole organism', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='Sequence Order', factor_type=isatools.model.OntologyAnnotation(term='sequence order', term_source=None, term_accession='', comments=[]), comments=[]), value=0, unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit=isatools.model.OntologyAnnotation(term='kg/m^3', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='cadmium chloride', term_source=None, term_accession='', comments=[]), unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=100.0, unit=isatools.model.OntologyAnnotation(term='s', term_source=None, term_accession='', comments=[]))], derives_from=[isatools.model.Source(name='GRP2_SBJ2', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[isatools.model.Comment(name='study step with treatment', value='YES')])], outputs=[isatools.model.Extract(name='AT0-S4-Extract-R1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='mRNA', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])]), isatools.model.Process(id="". name="AT0-S4-assay0---library_preparation-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=library_preparation_000_000,
#         name=assay0 - library_preparation,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - library_preparation
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library strategy)', term_source=None, term_accession='', comments=[]), comments=[]), value='RNA-SEQ', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library layout)', term_source=None, term_accession='', comments=[]), comments=[]), value='PAIRED', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=size)', term_source=None, term_accession='', comments=[]), comments=[]), value='40', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[isatools.model.Extract(name='AT0-S4-Extract-R1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='mRNA', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Process(id="". name="AT0-S4-assay0---nucleic-acid-sequencing-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=nucleic_acid_sequencing_000_000,
#         name=assay0 - nucleic acid sequencing,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=sequencing instrument)', term_source=None, term_accession='', comments=[]), comments=[]), value='DNBSEQ-T7', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[], outputs=[isatools.model.RawDataFile(filename='AT0-S4-raw_data_file-R1-', generated_from=[], comments=[])])]), isatools.model.Process(id="". name="AT0-S4-assay0---nucleic-acid-sequencing-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=nucleic_acid_sequencing_000_000,
#         name=assay0 - nucleic acid sequencing,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=sequencing instrument)', term_source=None, term_accession='', comments=[]), comments=[]), value='DNBSEQ-T7', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[], outputs=[isatools.model.RawDataFile(filename='AT0-S4-raw_data_file-R1-', generated_from=[], comments=[])]), isatools.model.Process(id="". name="AT0-S5-assay0---extraction-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=extraction_000,
#         name=assay0 - extraction,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[])
#         , date="None", performer="Unknown", inputs=[isatools.model.Sample(name='GRP2_SBJ1_SINGLE-TREATMENT-FIRST_SMP-whole-organism-1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='whole organism', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='Sequence Order', factor_type=isatools.model.OntologyAnnotation(term='sequence order', term_source=None, term_accession='', comments=[]), comments=[]), value=0, unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit=isatools.model.OntologyAnnotation(term='kg/m^3', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='cadmium chloride', term_source=None, term_accession='', comments=[]), unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=100.0, unit=isatools.model.OntologyAnnotation(term='s', term_source=None, term_accession='', comments=[]))], derives_from=[isatools.model.Source(name='GRP2_SBJ1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[isatools.model.Comment(name='study step with treatment', value='YES')])], outputs=[isatools.model.Extract(name='AT0-S5-Extract-R1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='mRNA', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])]), isatools.model.Process(id="". name="AT0-S5-assay0---library_preparation-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=library_preparation_000_000,
#         name=assay0 - library_preparation,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - library_preparation
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library strategy)', term_source=None, term_accession='', comments=[]), comments=[]), value='RNA-SEQ', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library layout)', term_source=None, term_accession='', comments=[]), comments=[]), value='PAIRED', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=size)', term_source=None, term_accession='', comments=[]), comments=[]), value='40', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[isatools.model.Extract(name='AT0-S5-Extract-R1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='mRNA', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Process(id="". name="AT0-S5-assay0---nucleic-acid-sequencing-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=nucleic_acid_sequencing_000_000,
#         name=assay0 - nucleic acid sequencing,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=sequencing instrument)', term_source=None, term_accession='', comments=[]), comments=[]), value='DNBSEQ-T7', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[], outputs=[isatools.model.RawDataFile(filename='AT0-S5-raw_data_file-R1-', generated_from=[], comments=[])])]), isatools.model.Process(id="". name="AT0-S5-assay0---nucleic-acid-sequencing-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=nucleic_acid_sequencing_000_000,
#         name=assay0 - nucleic acid sequencing,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=sequencing instrument)', term_source=None, term_accession='', comments=[]), comments=[]), value='DNBSEQ-T7', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[], outputs=[isatools.model.RawDataFile(filename='AT0-S5-raw_data_file-R1-', generated_from=[], comments=[])]), isatools.model.Process(id="". name="AT0-S6-assay0---extraction-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=extraction_000,
#         name=assay0 - extraction,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[])
#         , date="None", performer="Unknown", inputs=[isatools.model.Sample(name='GRP2_SBJ3_SINGLE-TREATMENT-FIRST_SMP-whole-organism-1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='whole organism', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='Sequence Order', factor_type=isatools.model.OntologyAnnotation(term='sequence order', term_source=None, term_accession='', comments=[]), comments=[]), value=0, unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit=isatools.model.OntologyAnnotation(term='kg/m^3', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='cadmium chloride', term_source=None, term_accession='', comments=[]), unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=100.0, unit=isatools.model.OntologyAnnotation(term='s', term_source=None, term_accession='', comments=[]))], derives_from=[isatools.model.Source(name='GRP2_SBJ3', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[isatools.model.Comment(name='study step with treatment', value='YES')])], outputs=[isatools.model.Extract(name='AT0-S6-Extract-R1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='mRNA', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])]), isatools.model.Process(id="". name="AT0-S6-assay0---library_preparation-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=library_preparation_000_000,
#         name=assay0 - library_preparation,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - library_preparation
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
# ...
#     name=sample collection
#     protocol_type=sample_collection
#     uri=
#     version=
#     parameters=2 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="2021-12-04", performer="Unknown", inputs=[isatools.model.Source(name='GRP2_SBJ3', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Sample(name='GRP2_SBJ3_SINGLE-TREATMENT-FIRST_SMP-whole-organism-1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='whole organism', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='Sequence Order', factor_type=isatools.model.OntologyAnnotation(term='sequence order', term_source=None, term_accession='', comments=[]), comments=[]), value=0, unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit=isatools.model.OntologyAnnotation(term='kg/m^3', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='cadmium chloride', term_source=None, term_accession='', comments=[]), unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=100.0, unit=isatools.model.OntologyAnnotation(term='s', term_source=None, term_accession='', comments=[]))], derives_from=[isatools.model.Source(name='GRP2_SBJ3', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[isatools.model.Comment(name='study step with treatment', value='YES')])]), isatools.model.Process(id="". name="None", executes_protocol=Protocol(
#     name=sample collection
#     protocol_type=sample_collection
#     uri=
#     version=
#     parameters=2 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="2021-12-04", performer="Unknown", inputs=[isatools.model.Source(name='GRP3_SBJ1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Sample(name='GRP3_SBJ1_SINGLE-TREATMENT-THIRD_SMP-whole-organism-1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='whole organism', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='Sequence Order', factor_type=isatools.model.OntologyAnnotation(term='sequence order', term_source=None, term_accession='', comments=[]), comments=[]), value=0, unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit=isatools.model.OntologyAnnotation(term='kg/m^3', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=50.0, unit=isatools.model.OntologyAnnotation(term='s', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='ethoprophos', term_source=None, term_accession='', comments=[]), unit=None)], derives_from=[isatools.model.Source(name='GRP3_SBJ1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[isatools.model.Comment(name='study step with treatment', value='YES')])]), isatools.model.Process(id="". name="None", executes_protocol=Protocol(
#     name=sample collection
#     protocol_type=sample_collection
#     uri=
#     version=
#     parameters=2 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="2021-12-04", performer="Unknown", inputs=[isatools.model.Source(name='GRP3_SBJ3', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Sample(name='GRP3_SBJ3_SINGLE-TREATMENT-THIRD_SMP-whole-organism-1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='whole organism', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='Sequence Order', factor_type=isatools.model.OntologyAnnotation(term='sequence order', term_source=None, term_accession='', comments=[]), comments=[]), value=0, unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit=isatools.model.OntologyAnnotation(term='kg/m^3', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=50.0, unit=isatools.model.OntologyAnnotation(term='s', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='ethoprophos', term_source=None, term_accession='', comments=[]), unit=None)], derives_from=[isatools.model.Source(name='GRP3_SBJ3', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[isatools.model.Comment(name='study step with treatment', value='YES')])]), isatools.model.Process(id="". name="None", executes_protocol=Protocol(
#     name=sample collection
#     protocol_type=sample_collection
#     uri=
#     version=
#     parameters=2 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="2021-12-04", performer="Unknown", inputs=[isatools.model.Source(name='GRP3_SBJ2', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Sample(name='GRP3_SBJ2_SINGLE-TREATMENT-THIRD_SMP-whole-organism-1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='whole organism', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='Sequence Order', factor_type=isatools.model.OntologyAnnotation(term='sequence order', term_source=None, term_accession='', comments=[]), comments=[]), value=0, unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit=isatools.model.OntologyAnnotation(term='kg/m^3', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=50.0, unit=isatools.model.OntologyAnnotation(term='s', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='ethoprophos', term_source=None, term_accession='', comments=[]), unit=None)], derives_from=[isatools.model.Source(name='GRP3_SBJ2', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[isatools.model.Comment(name='study step with treatment', value='YES')])])], other_material=[], characteristic_categories=[], comments=[], units=[])

# %%
treatment_assay = next(iter(study.assays))

# %%
treatment_assay.graph

# %%
[(process.name, getattr(process.prev_process, 'name', None), getattr(process.next_process, 'name', None)) for process in treatment_assay.process_sequence]
# Out:
# [('AT0-S1-assay0---extraction-Acquisition-R1',
#   None,
#   'AT0-S1-assay0---library_preparation-Acquisition-R1'),
#  ('AT0-S1-assay0---library_preparation-Acquisition-R1',
#   'AT0-S1-assay0---extraction-Acquisition-R1',
#   'AT0-S1-assay0---nucleic-acid-sequencing-Acquisition-R1'),
#  ('AT0-S1-assay0---nucleic-acid-sequencing-Acquisition-R1',
#   'AT0-S1-assay0---library_preparation-Acquisition-R1',
#   None),
#  ('AT0-S2-assay0---extraction-Acquisition-R1',
#   None,
#   'AT0-S2-assay0---library_preparation-Acquisition-R1'),
#  ('AT0-S2-assay0---library_preparation-Acquisition-R1',
#   'AT0-S2-assay0---extraction-Acquisition-R1',
#   'AT0-S2-assay0---nucleic-acid-sequencing-Acquisition-R1'),
#  ('AT0-S2-assay0---nucleic-acid-sequencing-Acquisition-R1',
#   'AT0-S2-assay0---library_preparation-Acquisition-R1',
#   None),
#  ('AT0-S3-assay0---extraction-Acquisition-R1',
#   None,
#   'AT0-S3-assay0---library_preparation-Acquisition-R1'),
#  ('AT0-S3-assay0---library_preparation-Acquisition-R1',
#   'AT0-S3-assay0---extraction-Acquisition-R1',
#   'AT0-S3-assay0---nucleic-acid-sequencing-Acquisition-R1'),
#  ('AT0-S3-assay0---nucleic-acid-sequencing-Acquisition-R1',
#   'AT0-S3-assay0---library_preparation-Acquisition-R1',
#   None),
#  ('AT0-S4-assay0---extraction-Acquisition-R1',
#   None,
#   'AT0-S4-assay0---library_preparation-Acquisition-R1'),
#  ('AT0-S4-assay0---library_preparation-Acquisition-R1',
#   'AT0-S4-assay0---extraction-Acquisition-R1',
#   'AT0-S4-assay0---nucleic-acid-sequencing-Acquisition-R1'),
#  ('AT0-S4-assay0---nucleic-acid-sequencing-Acquisition-R1',
#   'AT0-S4-assay0---library_preparation-Acquisition-R1',
#   None),
#  ('AT0-S5-assay0---extraction-Acquisition-R1',
#   None,
#   'AT0-S5-assay0---library_preparation-Acquisition-R1'),
#  ('AT0-S5-assay0---library_preparation-Acquisition-R1',
#   'AT0-S5-assay0---extraction-Acquisition-R1',
#   'AT0-S5-assay0---nucleic-acid-sequencing-Acquisition-R1'),
#  ('AT0-S5-assay0---nucleic-acid-sequencing-Acquisition-R1',
#   'AT0-S5-assay0---library_preparation-Acquisition-R1',
#   None),
#  ('AT0-S6-assay0---extraction-Acquisition-R1',
#   None,
#   'AT0-S6-assay0---library_preparation-Acquisition-R1'),
#  ('AT0-S6-assay0---library_preparation-Acquisition-R1',
#   'AT0-S6-assay0---extraction-Acquisition-R1',
#   'AT0-S6-assay0---nucleic-acid-sequencing-Acquisition-R1'),
#  ('AT0-S6-assay0---nucleic-acid-sequencing-Acquisition-R1',
#   'AT0-S6-assay0---library_preparation-Acquisition-R1',
#   None)]

# %%
a_graph = treatment_assay.graph

# %%
len(a_graph.nodes)
# Out:
# 30

# %%
isa_investigation.studies=[study]

# %%
isa_tables = dumpdf(isa_investigation)
# Out:
# 2021-12-04 10:35:40,294 [INFO]: isatab.py(_all_end_to_end_paths:1131) >> [120, 121, 122]
# 2021-12-04 10:35:40,295 [WARNING]: isatab.py(write_study_table_files:1194) >> [124, 123, 120, 126, 125, 128, 127, 130, 129, 121, 132, 131, 134, 133, 136, 135, 122, 138, 137, 140, 139]
# 2021-12-04 10:35:40,296 [INFO]: isatab.py(_longest_path_and_attrs:1091) >> [[120, 124, 123], [120, 126, 125], [120, 128, 127], [121, 130, 129], [121, 132, 131], [121, 134, 133], [122, 136, 135], [122, 138, 137], [122, 140, 139]]
# 2021-12-04 10:35:40,386 [INFO]: isatab.py(_all_end_to_end_paths:1131) >> [123, 125, 127, 129, 131, 133]
# 2021-12-04 10:35:40,387 [INFO]: isatab.py(_longest_path_and_attrs:1091) >> [[123, 141, 142, 143, 144], [125, 146, 147, 148, 149], [127, 151, 152, 153, 154], [129, 156, 157, 158, 159], [131, 161, 162, 163, 164], [133, 166, 167, 168, 169]]
# 2021-12-04 10:35:40,388 [INFO]: isatab.py(_longest_path_and_attrs:1091) >> [[123, 141, 142, 143, 144], [125, 146, 147, 148, 149], [127, 151, 152, 153, 154], [129, 156, 157, 158, 159], [131, 161, 162, 163, 164], [133, 166, 167, 168, 169]]
# 2021-12-04 10:35:40,442 [INFO]: isatab.py(_all_end_to_end_paths:1131) >> [135, 137, 139]
# 2021-12-04 10:35:40,444 [INFO]: isatab.py(_longest_path_and_attrs:1091) >> [[135, 171, 183, 184, 185, 192], [135, 171, 172, 173, 174, 175], [135, 171, 172, 173, 174, 177], [135, 171, 172, 173, 174, 179], [135, 171, 172, 173, 174, 181], [135, 171, 183, 184, 185, 186], [135, 171, 183, 184, 185, 188], [135, 171, 183, 184, 185, 190], [137, 194, 195, 196, 197, 198], [137, 194, 195, 196, 197, 200], [137, 194, 195, 196, 197, 202], [137, 194, 195, 196, 197, 204], [137, 194, 206, 207, 208, 209], [137, 194, 206, 207, 208, 211], [137, 194, 206, 207, 208, 213], [137, 194, 206, 207, 208, 215], [139, 217, 218, 219, 220, 221], [139, 217, 218, 219, 220, 223], [139, 217, 218, 219, 220, 225], [139, 217, 218, 219, 220, 227], [139, 217, 229, 230, 231, 232], [139, 217, 229, 230, 231, 234], [139, 217, 229, 230, 231, 236], [139, 217, 229, 230, 231, 238]]
# 2021-12-04 10:35:40,445 [INFO]: isatab.py(_longest_path_and_attrs:1091) >> [[135, 171, 183, 184, 185, 192], [135, 171, 172, 173, 174, 175], [135, 171, 172, 173, 174, 177], [135, 171, 172, 173, 174, 179], [135, 171, 172, 173, 174, 181], [135, 171, 183, 184, 185, 186], [135, 171, 183, 184, 185, 188], [135, 171, 183, 184, 185, 190], [137, 194, 195, 196, 197, 198], [137, 194, 195, 196, 197, 200], [137, 194, 195, 196, 197, 202], [137, 194, 195, 196, 197, 204], [137, 194, 206, 207, 208, 209], [137, 194, 206, 207, 208, 211], [137, 194, 206, 207, 208, 213], [137, 194, 206, 207, 208, 215], [139, 217, 218, 219, 220, 221], [139, 217, 218, 219, 220, 223], [139, 217, 218, 219, 220, 225], [139, 217, 218, 219, 220, 227], [139, 217, 229, 230, 231, 232], [139, 217, 229, 230, 231, 234], [139, 217, 229, 230, 231, 236], [139, 217, 229, 230, 231, 238]]

# %%
#[type(x) for x in study.assays[0].graph.nodes()]

# %%
#[(getattr(el, 'name', None), type(el))for el in treatment_assay.graph.nodes()]

# %%
from isatools.model import _build_assay_graph

# %%
gph = _build_assay_graph(treatment_assay.process_sequence)

# %%
[key for key in isa_tables.keys()]
# Out:
# ['s_study_01.txt',
#  'a_AT0_transcription-profiling_nucleotide-sequencing.txt',
#  'a_AT0_metabolite-profiling_mass-spectrometry.txt']

# %%
isa_tables['s_study_01.txt']
# Out:
#   Source Name Characteristics[Study Subject] Term Source REF  \
# 0   GRP1_SBJ1                          Human            NCIT
# 1   GRP1_SBJ1                          Human            NCIT
# 2   GRP1_SBJ1                          Human            NCIT
# 3   GRP2_SBJ3                          Human            NCIT
# 4   GRP2_SBJ3                          Human            NCIT
# 5   GRP2_SBJ3                          Human            NCIT
# 6   GRP3_SBJ2                          Human            NCIT
# 7   GRP3_SBJ2                          Human            NCIT
# 8   GRP3_SBJ2                          Human            NCIT
#
#                         Term Accession Number       Protocol REF  \
# 0  http://purl.obolibrary.org/obo/NCIT_C14225  sample collection
# 1  http://purl.obolibrary.org/obo/NCIT_C14225  sample collection
# 2  http://purl.obolibrary.org/obo/NCIT_C14225  sample collection
# 3  http://purl.obolibrary.org/obo/NCIT_C14225  sample collection
# 4  http://purl.obolibrary.org/obo/NCIT_C14225  sample collection
# 5  http://purl.obolibrary.org/obo/NCIT_C14225  sample collection
# 6  http://purl.obolibrary.org/obo/NCIT_C14225  sample collection
# 7  http://purl.obolibrary.org/obo/NCIT_C14225  sample collection
# 8  http://purl.obolibrary.org/obo/NCIT_C14225  sample collection
#
#   Parameter Value[Sampling order] Parameter Value[Study cell]        Date  \
# 0                             001     SINGLE TREATMENT SECOND  2021-12-04
# 1                             002     SINGLE TREATMENT SECOND  2021-12-04
# 2                             003     SINGLE TREATMENT SECOND  2021-12-04
# 3                             004      SINGLE TREATMENT FIRST  2021-12-04
# 4                             005      SINGLE TREATMENT FIRST  2021-12-04
# 5                             006      SINGLE TREATMENT FIRST  2021-12-04
# 6                             007      SINGLE TREATMENT THIRD  2021-12-04
# 7                             008      SINGLE TREATMENT THIRD  2021-12-04
# 8                             009      SINGLE TREATMENT THIRD  2021-12-04
#
#   Performer                                        Sample Name  \
# 0   Unknown  GRP1_SBJ2_SINGLE-TREATMENT-SECOND_SMP-whole-or...
# 1   Unknown  GRP1_SBJ3_SINGLE-TREATMENT-SECOND_SMP-whole-or...
# 2   Unknown  GRP1_SBJ1_SINGLE-TREATMENT-SECOND_SMP-whole-or...
# 3   Unknown  GRP2_SBJ2_SINGLE-TREATMENT-FIRST_SMP-whole-org...
# 4   Unknown  GRP2_SBJ1_SINGLE-TREATMENT-FIRST_SMP-whole-org...
# 5   Unknown  GRP2_SBJ3_SINGLE-TREATMENT-FIRST_SMP-whole-org...
# 6   Unknown  GRP3_SBJ1_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 7   Unknown  GRP3_SBJ3_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 8   Unknown  GRP3_SBJ2_SINGLE-TREATMENT-THIRD_SMP-whole-org...
#
#   Characteristics[organism part] Comment[study step with treatment]  \
# 0                 whole organism                                YES
# 1                 whole organism                                YES
# 2                 whole organism                                YES
# 3                 whole organism                                YES
# 4                 whole organism                                YES
# 5                 whole organism                                YES
# 6                 whole organism                                YES
# 7                 whole organism                                YES
# 8                 whole organism                                YES
#
#   Factor Value[Sequence Order] Factor Value[INTENSITY]    Unit  \
# 0                            0                       5  kg/m^3
# 1                            0                       5  kg/m^3
# 2                            0                       5  kg/m^3
# 3                            0                       5  kg/m^3
# 4                            0                       5  kg/m^3
# 5                            0                       5  kg/m^3
# 6                            0                       5  kg/m^3
# 7                            0                       5  kg/m^3
# 8                            0                       5  kg/m^3
#
#   Factor Value[AGENT] Factor Value[DURATION] Unit.1
# 0         ethoprophos                  100.0      s
# 1         ethoprophos                  100.0      s
# 2         ethoprophos                  100.0      s
# 3    cadmium chloride                  100.0      s
# 4    cadmium chloride                  100.0      s
# 5    cadmium chloride                  100.0      s
# 6         ethoprophos                   50.0      s
# 7         ethoprophos                   50.0      s
# 8         ethoprophos                   50.0      s

# %%
isa_tables['a_AT0_transcription-profiling_nucleotide-sequencing.txt']
# Out:
#                                          Sample Name  \
# 0  GRP1_SBJ1_SINGLE-TREATMENT-SECOND_SMP-whole-or...
# 1  GRP1_SBJ2_SINGLE-TREATMENT-SECOND_SMP-whole-or...
# 2  GRP1_SBJ3_SINGLE-TREATMENT-SECOND_SMP-whole-or...
# 3  GRP2_SBJ1_SINGLE-TREATMENT-FIRST_SMP-whole-org...
# 4  GRP2_SBJ2_SINGLE-TREATMENT-FIRST_SMP-whole-org...
# 5  GRP2_SBJ3_SINGLE-TREATMENT-FIRST_SMP-whole-org...
#
#   Comment[study step with treatment]         Protocol REF Performer  \
# 0                                YES  assay0 - extraction   Unknown
# 1                                YES  assay0 - extraction   Unknown
# 2                                YES  assay0 - extraction   Unknown
# 3                                YES  assay0 - extraction   Unknown
# 4                                YES  assay0 - extraction   Unknown
# 5                                YES  assay0 - extraction   Unknown
#
#         Extract Name Characteristics[extract type]  \
# 0  AT0-S3-Extract-R1                          mRNA
# 1  AT0-S1-Extract-R1                          mRNA
# 2  AT0-S2-Extract-R1                          mRNA
# 3  AT0-S5-Extract-R1                          mRNA
# 4  AT0-S4-Extract-R1                          mRNA
# 5  AT0-S6-Extract-R1                          mRNA
#
#                  Protocol REF.1  \
# 0  assay0 - library_preparation
# 1  assay0 - library_preparation
# 2  assay0 - library_preparation
# 3  assay0 - library_preparation
# 4  assay0 - library_preparation
# 5  assay0 - library_preparation
#
#   Parameter Value[OntologyAnnotation(term=library strategy)]  \
# 0                                            RNA-SEQ
# 1                                            RNA-SEQ
# 2                                            RNA-SEQ
# 3                                            RNA-SEQ
# 4                                            RNA-SEQ
# 5                                            RNA-SEQ
#
#   Parameter Value[OntologyAnnotation(term=library layout)]  \
# 0                                             PAIRED
# 1                                             PAIRED
# 2                                             PAIRED
# 3                                             PAIRED
# 4                                             PAIRED
# 5                                             PAIRED
#
#   Parameter Value[OntologyAnnotation(term=size)] Performer.1  \
# 0                                             40     Unknown
# 1                                             40     Unknown
# 2                                             40     Unknown
# 3                                             40     Unknown
# 4                                             40     Unknown
# 5                                             40     Unknown
#
#                      Protocol REF.2  \
# 0  assay0 - nucleic acid sequencing
# 1  assay0 - nucleic acid sequencing
# 2  assay0 - nucleic acid sequencing
# 3  assay0 - nucleic acid sequencing
# 4  assay0 - nucleic acid sequencing
# 5  assay0 - nucleic acid sequencing
#
#   Parameter Value[OntologyAnnotation(term=sequencing instrument)] Performer.2  \
# 0                                          DNBSEQ-T7                  Unknown
# 1                                          DNBSEQ-T7                  Unknown
# 2                                          DNBSEQ-T7                  Unknown
# 3                                          DNBSEQ-T7                  Unknown
# 4                                          DNBSEQ-T7                  Unknown
# 5                                          DNBSEQ-T7                  Unknown
#
#               Raw Data File
# 0  AT0-S3-raw_data_file-R1-
# 1  AT0-S1-raw_data_file-R1-
# 2  AT0-S2-raw_data_file-R1-
# 3  AT0-S5-raw_data_file-R1-
# 4  AT0-S4-raw_data_file-R1-
# 5  AT0-S6-raw_data_file-R1-

# %%
isa_tables['a_AT0_metabolite-profiling_mass-spectrometry.txt']
# Out:
#                                           Sample Name  \
# 0   GRP3_SBJ1_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 1   GRP3_SBJ1_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 2   GRP3_SBJ1_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 3   GRP3_SBJ1_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 4   GRP3_SBJ1_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 5   GRP3_SBJ1_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 6   GRP3_SBJ1_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 7   GRP3_SBJ1_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 8   GRP3_SBJ2_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 9   GRP3_SBJ2_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 10  GRP3_SBJ2_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 11  GRP3_SBJ2_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 12  GRP3_SBJ2_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 13  GRP3_SBJ2_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 14  GRP3_SBJ2_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 15  GRP3_SBJ2_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 16  GRP3_SBJ3_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 17  GRP3_SBJ3_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 18  GRP3_SBJ3_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 19  GRP3_SBJ3_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 20  GRP3_SBJ3_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 21  GRP3_SBJ3_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 22  GRP3_SBJ3_SINGLE-TREATMENT-THIRD_SMP-whole-org...
# 23  GRP3_SBJ3_SINGLE-TREATMENT-THIRD_SMP-whole-org...
#
#    Comment[study step with treatment]         Protocol REF Performer  \
# 0                                 YES  assay0 - extraction   Unknown
# 1                                 YES  assay0 - extraction   Unknown
# 2                                 YES  assay0 - extraction   Unknown
# 3                                 YES  assay0 - extraction   Unknown
# 4                                 YES  assay0 - extraction   Unknown
# 5                                 YES  assay0 - extraction   Unknown
# 6                                 YES  assay0 - extraction   Unknown
# 7                                 YES  assay0 - extraction   Unknown
# 8                                 YES  assay0 - extraction   Unknown
# 9                                 YES  assay0 - extraction   Unknown
# 10                                YES  assay0 - extraction   Unknown
# 11                                YES  assay0 - extraction   Unknown
# 12                                YES  assay0 - extraction   Unknown
# 13                                YES  assay0 - extraction   Unknown
# 14                                YES  assay0 - extraction   Unknown
# 15                                YES  assay0 - extraction   Unknown
# 16                                YES  assay0 - extraction   Unknown
# 17                                YES  assay0 - extraction   Unknown
# 18                                YES  assay0 - extraction   Unknown
# 19                                YES  assay0 - extraction   Unknown
# 20                                YES  assay0 - extraction   Unknown
# 21                                YES  assay0 - extraction   Unknown
# 22                                YES  assay0 - extraction   Unknown
# 23                                YES  assay0 - extraction   Unknown
#
#          Extract Name Characteristics[extract type]           Protocol REF.1  \
# 0   AT0-S1-Extract-R2                polar fraction  assay0 - derivatization
# 1   AT0-S1-Extract-R1                        lipids  assay0 - derivatization
# 2   AT0-S1-Extract-R1                        lipids  assay0 - derivatization
# 3   AT0-S1-Extract-R1                        lipids  assay0 - derivatization
# 4   AT0-S1-Extract-R1                        lipids  assay0 - derivatization
# 5   AT0-S1-Extract-R2                polar fraction  assay0 - derivatization
# 6   AT0-S1-Extract-R2                polar fraction  assay0 - derivatization
# 7   AT0-S1-Extract-R2                polar fraction  assay0 - derivatization
# 8   AT0-S3-Extract-R2                polar fraction  assay0 - derivatization
# 9   AT0-S3-Extract-R2                polar fraction  assay0 - derivatization
# 10  AT0-S3-Extract-R1                        lipids  assay0 - derivatization
# 11  AT0-S3-Extract-R1                        lipids  assay0 - derivatization
# 12  AT0-S3-Extract-R1                        lipids  assay0 - derivatization
# 13  AT0-S3-Extract-R1                        lipids  assay0 - derivatization
# 14  AT0-S3-Extract-R2                polar fraction  assay0 - derivatization
# 15  AT0-S3-Extract-R2                polar fraction  assay0 - derivatization
# 16  AT0-S2-Extract-R2                polar fraction  assay0 - derivatization
# 17  AT0-S2-Extract-R2                polar fraction  assay0 - derivatization
# 18  AT0-S2-Extract-R2                polar fraction  assay0 - derivatization
# 19  AT0-S2-Extract-R1                        lipids  assay0 - derivatization
# 20  AT0-S2-Extract-R1                        lipids  assay0 - derivatization
# 21  AT0-S2-Extract-R1                        lipids  assay0 - derivatization
# 22  AT0-S2-Extract-R2                polar fraction  assay0 - derivatization
# 23  AT0-S2-Extract-R1                        lipids  assay0 - derivatization
#
#    Parameter Value[derivatization] Performer.1 Labeled Extract Name  \
# 0     bis(trimethylsilyl)acetamide     Unknown         AT0-S1-LE-R2
# 1     bis(trimethylsilyl)acetamide     Unknown         AT0-S1-LE-R1
# 2     bis(trimethylsilyl)acetamide     Unknown         AT0-S1-LE-R1
# 3     bis(trimethylsilyl)acetamide     Unknown         AT0-S1-LE-R1
# 4     bis(trimethylsilyl)acetamide     Unknown         AT0-S1-LE-R1
# 5     bis(trimethylsilyl)acetamide     Unknown         AT0-S1-LE-R2
# 6     bis(trimethylsilyl)acetamide     Unknown         AT0-S1-LE-R2
# 7     bis(trimethylsilyl)acetamide     Unknown         AT0-S1-LE-R2
# 8     bis(trimethylsilyl)acetamide     Unknown         AT0-S3-LE-R2
# 9     bis(trimethylsilyl)acetamide     Unknown         AT0-S3-LE-R2
# 10    bis(trimethylsilyl)acetamide     Unknown         AT0-S3-LE-R1
# 11    bis(trimethylsilyl)acetamide     Unknown         AT0-S3-LE-R1
# 12    bis(trimethylsilyl)acetamide     Unknown         AT0-S3-LE-R1
# 13    bis(trimethylsilyl)acetamide     Unknown         AT0-S3-LE-R1
# 14    bis(trimethylsilyl)acetamide     Unknown         AT0-S3-LE-R2
# 15    bis(trimethylsilyl)acetamide     Unknown         AT0-S3-LE-R2
# 16    bis(trimethylsilyl)acetamide     Unknown         AT0-S2-LE-R2
# 17    bis(trimethylsilyl)acetamide     Unknown         AT0-S2-LE-R2
# 18    bis(trimethylsilyl)acetamide     Unknown         AT0-S2-LE-R2
# 19    bis(trimethylsilyl)acetamide     Unknown         AT0-S2-LE-R1
# 20    bis(trimethylsilyl)acetamide     Unknown         AT0-S2-LE-R1
# 21    bis(trimethylsilyl)acetamide     Unknown         AT0-S2-LE-R1
# 22    bis(trimethylsilyl)acetamide     Unknown         AT0-S2-LE-R2
# 23    bis(trimethylsilyl)acetamide     Unknown         AT0-S2-LE-R1
#
#                 Protocol REF.2 Parameter Value[instrument]  \
# 0   assay0 - mass spectrometry                Agilent QTOF
# 1   assay0 - mass spectrometry                Agilent QTOF
# 2   assay0 - mass spectrometry                Agilent QTOF
# 3   assay0 - mass spectrometry                Agilent QTOF
# 4   assay0 - mass spectrometry                Agilent QTOF
# 5   assay0 - mass spectrometry                Agilent QTOF
# 6   assay0 - mass spectrometry                Agilent QTOF
# 7   assay0 - mass spectrometry                Agilent QTOF
# 8   assay0 - mass spectrometry                Agilent QTOF
# 9   assay0 - mass spectrometry                Agilent QTOF
# 10  assay0 - mass spectrometry                Agilent QTOF
# 11  assay0 - mass spectrometry                Agilent QTOF
# 12  assay0 - mass spectrometry                Agilent QTOF
# 13  assay0 - mass spectrometry                Agilent QTOF
# 14  assay0 - mass spectrometry                Agilent QTOF
# 15  assay0 - mass spectrometry                Agilent QTOF
# 16  assay0 - mass spectrometry                Agilent QTOF
# 17  assay0 - mass spectrometry                Agilent QTOF
# 18  assay0 - mass spectrometry                Agilent QTOF
# 19  assay0 - mass spectrometry                Agilent QTOF
# 20  assay0 - mass spectrometry                Agilent QTOF
# 21  assay0 - mass spectrometry                Agilent QTOF
# 22  assay0 - mass spectrometry                Agilent QTOF
# 23  assay0 - mass spectrometry                Agilent QTOF
#
#    Parameter Value[injection_mode] Parameter Value[acquisition_mode]  \
# 0                               GC                     positive mode
# 1                               GC                     positive mode
# 2                               GC                     positive mode
# 3                               GC                     negative mode
# 4                               GC                     negative mode
# 5                               GC                     negative mode
# 6                               GC                     negative mode
# 7                               GC                     positive mode
# 8                               GC                     negative mode
# 9                               GC                     negative mode
# 10                              GC                     negative mode
# 11                              GC                     negative mode
# 12                              GC                     positive mode
# 13                              GC                     positive mode
# 14                              GC                     positive mode
# 15                              GC                     positive mode
# 16                              GC                     positive mode
# 17                              GC                     negative mode
# 18                              GC                     negative mode
# 19                              GC                     negative mode
# 20                              GC                     positive mode
# 21                              GC                     positive mode
# 22                              GC                     positive mode
# 23                              GC                     negative mode
#
#    Performer.2            Raw Spectral Data File
# 0      Unknown  AT0-S1-raw-spectral-data-file-R8
# 1      Unknown  AT0-S1-raw-spectral-data-file-R1
# 2      Unknown  AT0-S1-raw-spectral-data-file-R2
# 3      Unknown  AT0-S1-raw-spectral-data-file-R3
# 4      Unknown  AT0-S1-raw-spectral-data-file-R4
# 5      Unknown  AT0-S1-raw-spectral-data-file-R5
# 6      Unknown  AT0-S1-raw-spectral-data-file-R6
# 7      Unknown  AT0-S1-raw-spectral-data-file-R7
# 8      Unknown  AT0-S3-raw-spectral-data-file-R6
# 9      Unknown  AT0-S3-raw-spectral-data-file-R5
# 10     Unknown  AT0-S3-raw-spectral-data-file-R4
# 11     Unknown  AT0-S3-raw-spectral-data-file-R3
# 12     Unknown  AT0-S3-raw-spectral-data-file-R2
# 13     Unknown  AT0-S3-raw-spectral-data-file-R1
# 14     Unknown  AT0-S3-raw-spectral-data-file-R8
# 15     Unknown  AT0-S3-raw-spectral-data-file-R7
# 16     Unknown  AT0-S2-raw-spectral-data-file-R8
# 17     Unknown  AT0-S2-raw-spectral-data-file-R6
# 18     Unknown  AT0-S2-raw-spectral-data-file-R5
# 19     Unknown  AT0-S2-raw-spectral-data-file-R3
# 20     Unknown  AT0-S2-raw-spectral-data-file-R2
# 21     Unknown  AT0-S2-raw-spectral-data-file-R1
# 22     Unknown  AT0-S2-raw-spectral-data-file-R7
# 23     Unknown  AT0-S2-raw-spectral-data-file-R4

# %%
final_dir = os.path.abspath(os.path.join('notebook-output', 'sd-test'))

# %% [markdown]
# ### 7. Serialization as ISA-JSON and ISA-Tab

# %%
isa_j = json.dumps(isa_investigation, cls=ISAJSONEncoder, sort_keys=True, indent=4, separators=(',', ': '))
open(os.path.join(final_dir,"isa_as_json_from_dumps2.json"),"w").write(isa_j) # this call write the string 'isa_j' to the file called 'isa_as_json_from_dumps.json'
# Out:
# 199796

# %%
isatab.dump(isa_obj=isa_investigation, output_path=final_dir)
# Out:
# 2021-12-04 10:36:12,087 [INFO]: isatab.py(_all_end_to_end_paths:1131) >> [120, 121, 122]
# 2021-12-04 10:36:12,088 [WARNING]: isatab.py(write_study_table_files:1194) >> [124, 123, 120, 126, 125, 128, 127, 130, 129, 121, 132, 131, 134, 133, 136, 135, 122, 138, 137, 140, 139]
# 2021-12-04 10:36:12,088 [INFO]: isatab.py(_longest_path_and_attrs:1091) >> [[120, 124, 123], [120, 126, 125], [120, 128, 127], [121, 130, 129], [121, 132, 131], [121, 134, 133], [122, 136, 135], [122, 138, 137], [122, 140, 139]]
# 2021-12-04 10:36:12,150 [INFO]: isatab.py(_all_end_to_end_paths:1131) >> [123, 125, 127, 129, 131, 133]
# 2021-12-04 10:36:12,151 [INFO]: isatab.py(_longest_path_and_attrs:1091) >> [[123, 141, 142, 143, 144], [125, 146, 147, 148, 149], [127, 151, 152, 153, 154], [129, 156, 157, 158, 159], [131, 161, 162, 163, 164], [133, 166, 167, 168, 169]]
# 2021-12-04 10:36:12,152 [INFO]: isatab.py(_longest_path_and_attrs:1091) >> [[123, 141, 142, 143, 144], [125, 146, 147, 148, 149], [127, 151, 152, 153, 154], [129, 156, 157, 158, 159], [131, 161, 162, 163, 164], [133, 166, 167, 168, 169]]
# 2021-12-04 10:36:12,212 [INFO]: isatab.py(_all_end_to_end_paths:1131) >> [135, 137, 139]
# 2021-12-04 10:36:12,214 [INFO]: isatab.py(_longest_path_and_attrs:1091) >> [[135, 171, 183, 184, 185, 192], [135, 171, 172, 173, 174, 175], [135, 171, 172, 173, 174, 177], [135, 171, 172, 173, 174, 179], [135, 171, 172, 173, 174, 181], [135, 171, 183, 184, 185, 186], [135, 171, 183, 184, 185, 188], [135, 171, 183, 184, 185, 190], [137, 194, 195, 196, 197, 198], [137, 194, 195, 196, 197, 200], [137, 194, 195, 196, 197, 202], [137, 194, 195, 196, 197, 204], [137, 194, 206, 207, 208, 209], [137, 194, 206, 207, 208, 211], [137, 194, 206, 207, 208, 213], [137, 194, 206, 207, 208, 215], [139, 217, 218, 219, 220, 221], [139, 217, 218, 219, 220, 223], [139, 217, 218, 219, 220, 225], [139, 217, 218, 219, 220, 227], [139, 217, 229, 230, 231, 232], [139, 217, 229, 230, 231, 234], [139, 217, 229, 230, 231, 236], [139, 217, 229, 230, 231, 238]]
# 2021-12-04 10:36:12,215 [INFO]: isatab.py(_longest_path_and_attrs:1091) >> [[135, 171, 183, 184, 185, 192], [135, 171, 172, 173, 174, 175], [135, 171, 172, 173, 174, 177], [135, 171, 172, 173, 174, 179], [135, 171, 172, 173, 174, 181], [135, 171, 183, 184, 185, 186], [135, 171, 183, 184, 185, 188], [135, 171, 183, 184, 185, 190], [137, 194, 195, 196, 197, 198], [137, 194, 195, 196, 197, 200], [137, 194, 195, 196, 197, 202], [137, 194, 195, 196, 197, 204], [137, 194, 206, 207, 208, 209], [137, 194, 206, 207, 208, 211], [137, 194, 206, 207, 208, 213], [137, 194, 206, 207, 208, 215], [139, 217, 218, 219, 220, 221], [139, 217, 218, 219, 220, 223], [139, 217, 218, 219, 220, 225], [139, 217, 218, 219, 220, 227], [139, 217, 229, 230, 231, 232], [139, 217, 229, 230, 231, 234], [139, 217, 229, 230, 231, 236], [139, 217, 229, 230, 231, 238]]
# isatools.model.Investigation(identifier='', filename='', title='', submission_date='', public_release_date='', ontology_source_references=[isatools.model.OntologySource(name='CHEBI', file='', version='', description='Chemical Entities of Biological Interest', comments=[]), isatools.model.OntologySource(name='CHMO', file='', version='', description='Chemical Methods Ontology', comments=[]), isatools.model.OntologySource(name='MSIO', file='', version='', description='Metabolite Standards Initiative Ontology', comments=[]), isatools.model.OntologySource(name='NCBITAXON', file='', version='', description='NCBI organismal classification', comments=[]), isatools.model.OntologySource(name='NCIT', file='', version='', description='NCI Thesaurus OBO Edition', comments=[]), isatools.model.OntologySource(name='OBI', file='', version='', description='Ontology for Biomedical Investigations', comments=[]), isatools.model.OntologySource(name='UO', file='', version='', description='UO - the Unit Ontology', comments=[]), isatools.model.OntologySource(name='PATO', file='', version='', description='PATO - the Phenotype And Trait Ontology', comments=[]), isatools.model.OntologySource(name='UBERON', file='', version='', description='Uber-anatomy ontology', comments=[])], publications=[], contacts=[], studies=[isatools.model.Study(filename='s_study_01.txt', identifier='s_01', title='Study Design', description='None', submission_date='', public_release_date='', contacts=[], design_descriptors=[], publications=[], factors=[isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), isatools.model.StudyFactor(name='Sequence Order', factor_type=isatools.model.OntologyAnnotation(term='sequence order', term_source=None, term_accession='', comments=[]), comments=[])], protocols=[isatools.model.Protocol(name='sample collection', protocol_type=isatools.model.OntologyAnnotation(term='sample_collection', term_source=None, term_accession='', comments=[]), uri='', version='', parameters=[isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='Sampling order', term_source=None, term_accession='', comments=[]), comments=[]), isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='Study cell', term_source=None, term_accession='', comments=[]), comments=[])], components=[], comments=[]), isatools.create.model.ProtocolNode(id=extraction_000, name=assay0 - extraction, protocol_type=OntologyAnnotation(
#     term=assay0 - extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[]), isatools.create.model.ProtocolNode(id=mass_spectrometry_001_000, name=assay0 - mass spectrometry, protocol_type=OntologyAnnotation(
#     term=assay0 - mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTOF', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='GC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='negative mode', unit=None, comments=[])]), isatools.create.model.ProtocolNode(id=library_preparation_000_000, name=assay0 - library_preparation, protocol_type=OntologyAnnotation(
#     term=assay0 - library_preparation
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library strategy)', term_source=None, term_accession='', comments=[]), comments=[]), value='RNA-SEQ', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library layout)', term_source=None, term_accession='', comments=[]), comments=[]), value='PAIRED', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=size)', term_source=None, term_accession='', comments=[]), comments=[]), value='40', unit=None, comments=[])]), isatools.create.model.ProtocolNode(id=derivatization_000_001, name=assay0 - derivatization, protocol_type=OntologyAnnotation(
#     term=assay0 - derivatization
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='derivatization', term_source=None, term_accession='', comments=[]), comments=[]), value='bis(trimethylsilyl)acetamide', unit=None, comments=[])]), isatools.create.model.ProtocolNode(id=derivatization_000_000, name=assay0 - derivatization, protocol_type=OntologyAnnotation(
#     term=assay0 - derivatization
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='derivatization', term_source=None, term_accession='', comments=[]), comments=[]), value='bis(trimethylsilyl)acetamide', unit=None, comments=[])]), isatools.create.model.ProtocolNode(id=nucleic_acid_sequencing_000_000, name=assay0 - nucleic acid sequencing, protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=sequencing instrument)', term_source=None, term_accession='', comments=[]), comments=[]), value='DNBSEQ-T7', unit=None, comments=[])]), isatools.create.model.ProtocolNode(id=mass_spectrometry_000_001, name=assay0 - mass spectrometry, protocol_type=OntologyAnnotation(
#     term=assay0 - mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTOF', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='GC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='positive mode', unit=None, comments=[])]), isatools.create.model.ProtocolNode(id=mass_spectrometry_001_001, name=assay0 - mass spectrometry, protocol_type=OntologyAnnotation(
#     term=assay0 - mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTOF', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='GC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='negative mode', unit=None, comments=[])]), isatools.create.model.ProtocolNode(id=mass_spectrometry_000_000, name=assay0 - mass spectrometry, protocol_type=OntologyAnnotation(
#     term=assay0 - mass spectrometry
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ), uri=, description=, version=, parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='instrument', term_source=None, term_accession='', comments=[]), comments=[]), value='Agilent QTOF', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='injection_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='GC', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='acquisition_mode', term_source=None, term_accession='', comments=[]), comments=[]), value='positive mode', unit=None, comments=[])])], assays=[isatools.model.Assay(measurement_type=isatools.model.OntologyAnnotation(term='transcription profiling', term_source=None, term_accession='', comments=[]), technology_type=isatools.model.OntologyAnnotation(term='nucleotide sequencing', term_source=None, term_accession='', comments=[]), technology_platform='', filename='a_AT0_transcription-profiling_nucleotide-sequencing.txt', data_files=[isatools.model.RawDataFile(filename='AT0-S1-raw_data_file-R1-', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='AT0-S2-raw_data_file-R1-', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='AT0-S3-raw_data_file-R1-', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='AT0-S4-raw_data_file-R1-', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='AT0-S5-raw_data_file-R1-', generated_from=[], comments=[]), isatools.model.RawDataFile(filename='AT0-S6-raw_data_file-R1-', generated_from=[], comments=[])], samples=[], process_sequence=[isatools.model.Process(id="". name="AT0-S1-assay0---extraction-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=extraction_000,
#         name=assay0 - extraction,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[])
#         , date="None", performer="Unknown", inputs=[isatools.model.Sample(name='GRP1_SBJ2_SINGLE-TREATMENT-SECOND_SMP-whole-organism-1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='whole organism', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='Sequence Order', factor_type=isatools.model.OntologyAnnotation(term='sequence order', term_source=None, term_accession='', comments=[]), comments=[]), value=0, unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit=isatools.model.OntologyAnnotation(term='kg/m^3', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='ethoprophos', term_source=None, term_accession='', comments=[]), unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=100.0, unit=isatools.model.OntologyAnnotation(term='s', term_source=None, term_accession='', comments=[]))], derives_from=[isatools.model.Source(name='GRP1_SBJ2', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[isatools.model.Comment(name='study step with treatment', value='YES')])], outputs=[isatools.model.Extract(name='AT0-S1-Extract-R1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='mRNA', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])]), isatools.model.Process(id="". name="AT0-S1-assay0---library_preparation-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=library_preparation_000_000,
#         name=assay0 - library_preparation,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - library_preparation
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library strategy)', term_source=None, term_accession='', comments=[]), comments=[]), value='RNA-SEQ', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library layout)', term_source=None, term_accession='', comments=[]), comments=[]), value='PAIRED', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=size)', term_source=None, term_accession='', comments=[]), comments=[]), value='40', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[isatools.model.Extract(name='AT0-S1-Extract-R1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='mRNA', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Process(id="". name="AT0-S1-assay0---nucleic-acid-sequencing-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=nucleic_acid_sequencing_000_000,
#         name=assay0 - nucleic acid sequencing,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=sequencing instrument)', term_source=None, term_accession='', comments=[]), comments=[]), value='DNBSEQ-T7', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[], outputs=[isatools.model.RawDataFile(filename='AT0-S1-raw_data_file-R1-', generated_from=[], comments=[])])]), isatools.model.Process(id="". name="AT0-S1-assay0---nucleic-acid-sequencing-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=nucleic_acid_sequencing_000_000,
#         name=assay0 - nucleic acid sequencing,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=sequencing instrument)', term_source=None, term_accession='', comments=[]), comments=[]), value='DNBSEQ-T7', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[], outputs=[isatools.model.RawDataFile(filename='AT0-S1-raw_data_file-R1-', generated_from=[], comments=[])]), isatools.model.Process(id="". name="AT0-S2-assay0---extraction-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=extraction_000,
#         name=assay0 - extraction,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[])
#         , date="None", performer="Unknown", inputs=[isatools.model.Sample(name='GRP1_SBJ3_SINGLE-TREATMENT-SECOND_SMP-whole-organism-1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='whole organism', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='Sequence Order', factor_type=isatools.model.OntologyAnnotation(term='sequence order', term_source=None, term_accession='', comments=[]), comments=[]), value=0, unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit=isatools.model.OntologyAnnotation(term='kg/m^3', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='ethoprophos', term_source=None, term_accession='', comments=[]), unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=100.0, unit=isatools.model.OntologyAnnotation(term='s', term_source=None, term_accession='', comments=[]))], derives_from=[isatools.model.Source(name='GRP1_SBJ3', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[isatools.model.Comment(name='study step with treatment', value='YES')])], outputs=[isatools.model.Extract(name='AT0-S2-Extract-R1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='mRNA', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])]), isatools.model.Process(id="". name="AT0-S2-assay0---library_preparation-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=library_preparation_000_000,
#         name=assay0 - library_preparation,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - library_preparation
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library strategy)', term_source=None, term_accession='', comments=[]), comments=[]), value='RNA-SEQ', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library layout)', term_source=None, term_accession='', comments=[]), comments=[]), value='PAIRED', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=size)', term_source=None, term_accession='', comments=[]), comments=[]), value='40', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[isatools.model.Extract(name='AT0-S2-Extract-R1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='mRNA', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Process(id="". name="AT0-S2-assay0---nucleic-acid-sequencing-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=nucleic_acid_sequencing_000_000,
#         name=assay0 - nucleic acid sequencing,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=sequencing instrument)', term_source=None, term_accession='', comments=[]), comments=[]), value='DNBSEQ-T7', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[], outputs=[isatools.model.RawDataFile(filename='AT0-S2-raw_data_file-R1-', generated_from=[], comments=[])])]), isatools.model.Process(id="". name="AT0-S2-assay0---nucleic-acid-sequencing-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=nucleic_acid_sequencing_000_000,
#         name=assay0 - nucleic acid sequencing,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=sequencing instrument)', term_source=None, term_accession='', comments=[]), comments=[]), value='DNBSEQ-T7', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[], outputs=[isatools.model.RawDataFile(filename='AT0-S2-raw_data_file-R1-', generated_from=[], comments=[])]), isatools.model.Process(id="". name="AT0-S3-assay0---extraction-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=extraction_000,
#         name=assay0 - extraction,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[])
#         , date="None", performer="Unknown", inputs=[isatools.model.Sample(name='GRP1_SBJ1_SINGLE-TREATMENT-SECOND_SMP-whole-organism-1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='whole organism', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='Sequence Order', factor_type=isatools.model.OntologyAnnotation(term='sequence order', term_source=None, term_accession='', comments=[]), comments=[]), value=0, unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit=isatools.model.OntologyAnnotation(term='kg/m^3', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='ethoprophos', term_source=None, term_accession='', comments=[]), unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=100.0, unit=isatools.model.OntologyAnnotation(term='s', term_source=None, term_accession='', comments=[]))], derives_from=[isatools.model.Source(name='GRP1_SBJ1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[isatools.model.Comment(name='study step with treatment', value='YES')])], outputs=[isatools.model.Extract(name='AT0-S3-Extract-R1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='mRNA', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])]), isatools.model.Process(id="". name="AT0-S3-assay0---library_preparation-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=library_preparation_000_000,
#         name=assay0 - library_preparation,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - library_preparation
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library strategy)', term_source=None, term_accession='', comments=[]), comments=[]), value='RNA-SEQ', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library layout)', term_source=None, term_accession='', comments=[]), comments=[]), value='PAIRED', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=size)', term_source=None, term_accession='', comments=[]), comments=[]), value='40', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[isatools.model.Extract(name='AT0-S3-Extract-R1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='mRNA', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Process(id="". name="AT0-S3-assay0---nucleic-acid-sequencing-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=nucleic_acid_sequencing_000_000,
#         name=assay0 - nucleic acid sequencing,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=sequencing instrument)', term_source=None, term_accession='', comments=[]), comments=[]), value='DNBSEQ-T7', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[], outputs=[isatools.model.RawDataFile(filename='AT0-S3-raw_data_file-R1-', generated_from=[], comments=[])])]), isatools.model.Process(id="". name="AT0-S3-assay0---nucleic-acid-sequencing-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=nucleic_acid_sequencing_000_000,
#         name=assay0 - nucleic acid sequencing,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=sequencing instrument)', term_source=None, term_accession='', comments=[]), comments=[]), value='DNBSEQ-T7', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[], outputs=[isatools.model.RawDataFile(filename='AT0-S3-raw_data_file-R1-', generated_from=[], comments=[])]), isatools.model.Process(id="". name="AT0-S4-assay0---extraction-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=extraction_000,
#         name=assay0 - extraction,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[])
#         , date="None", performer="Unknown", inputs=[isatools.model.Sample(name='GRP2_SBJ2_SINGLE-TREATMENT-FIRST_SMP-whole-organism-1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='whole organism', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='Sequence Order', factor_type=isatools.model.OntologyAnnotation(term='sequence order', term_source=None, term_accession='', comments=[]), comments=[]), value=0, unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit=isatools.model.OntologyAnnotation(term='kg/m^3', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='cadmium chloride', term_source=None, term_accession='', comments=[]), unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=100.0, unit=isatools.model.OntologyAnnotation(term='s', term_source=None, term_accession='', comments=[]))], derives_from=[isatools.model.Source(name='GRP2_SBJ2', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[isatools.model.Comment(name='study step with treatment', value='YES')])], outputs=[isatools.model.Extract(name='AT0-S4-Extract-R1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='mRNA', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])]), isatools.model.Process(id="". name="AT0-S4-assay0---library_preparation-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=library_preparation_000_000,
#         name=assay0 - library_preparation,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - library_preparation
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library strategy)', term_source=None, term_accession='', comments=[]), comments=[]), value='RNA-SEQ', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library layout)', term_source=None, term_accession='', comments=[]), comments=[]), value='PAIRED', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=size)', term_source=None, term_accession='', comments=[]), comments=[]), value='40', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[isatools.model.Extract(name='AT0-S4-Extract-R1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='mRNA', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Process(id="". name="AT0-S4-assay0---nucleic-acid-sequencing-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=nucleic_acid_sequencing_000_000,
#         name=assay0 - nucleic acid sequencing,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=sequencing instrument)', term_source=None, term_accession='', comments=[]), comments=[]), value='DNBSEQ-T7', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[], outputs=[isatools.model.RawDataFile(filename='AT0-S4-raw_data_file-R1-', generated_from=[], comments=[])])]), isatools.model.Process(id="". name="AT0-S4-assay0---nucleic-acid-sequencing-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=nucleic_acid_sequencing_000_000,
#         name=assay0 - nucleic acid sequencing,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=sequencing instrument)', term_source=None, term_accession='', comments=[]), comments=[]), value='DNBSEQ-T7', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[], outputs=[isatools.model.RawDataFile(filename='AT0-S4-raw_data_file-R1-', generated_from=[], comments=[])]), isatools.model.Process(id="". name="AT0-S5-assay0---extraction-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=extraction_000,
#         name=assay0 - extraction,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - extraction
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[])
#         , date="None", performer="Unknown", inputs=[isatools.model.Sample(name='GRP2_SBJ1_SINGLE-TREATMENT-FIRST_SMP-whole-organism-1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='whole organism', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='Sequence Order', factor_type=isatools.model.OntologyAnnotation(term='sequence order', term_source=None, term_accession='', comments=[]), comments=[]), value=0, unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit=isatools.model.OntologyAnnotation(term='kg/m^3', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='cadmium chloride', term_source=None, term_accession='', comments=[]), unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=100.0, unit=isatools.model.OntologyAnnotation(term='s', term_source=None, term_accession='', comments=[]))], derives_from=[isatools.model.Source(name='GRP2_SBJ1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[isatools.model.Comment(name='study step with treatment', value='YES')])], outputs=[isatools.model.Extract(name='AT0-S5-Extract-R1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='mRNA', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])]), isatools.model.Process(id="". name="AT0-S5-assay0---library_preparation-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=library_preparation_000_000,
#         name=assay0 - library_preparation,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - library_preparation
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library strategy)', term_source=None, term_accession='', comments=[]), comments=[]), value='RNA-SEQ', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=library layout)', term_source=None, term_accession='', comments=[]), comments=[]), value='PAIRED', unit=None, comments=[]), isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=size)', term_source=None, term_accession='', comments=[]), comments=[]), value='40', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[isatools.model.Extract(name='AT0-S5-Extract-R1', type='Extract Name', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='extract type', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='mRNA', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Process(id="". name="AT0-S5-assay0---nucleic-acid-sequencing-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=nucleic_acid_sequencing_000_000,
#         name=assay0 - nucleic acid sequencing,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
#         parameter_values=[isatools.model.ParameterValue(category=isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='OntologyAnnotation(term=sequencing instrument)', term_source=None, term_accession='', comments=[]), comments=[]), value='DNBSEQ-T7', unit=None, comments=[])])
#         , date="None", performer="Unknown", inputs=[], outputs=[isatools.model.RawDataFile(filename='AT0-S5-raw_data_file-R1-', generated_from=[], comments=[])])]), isatools.model.Process(id="". name="AT0-S5-assay0---nucleic-acid-sequencing-Acquisition-R1", executes_protocol=ProtocolNode(
#         id=nucleic_acid_sequencing_000_000,
#         name=assay0 - nucleic acid sequencing,
#         protocol_type=OntologyAnnotation(
#     term=assay0 - nucleic acid sequencing
#     term_source=
#     term_accession=
#     comments=0 Comment objects
# ),
#         uri=,
#         description=,
#         version=,
# ...
#     name=sample collection
#     protocol_type=sample_collection
#     uri=
#     version=
#     parameters=2 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="2021-12-04", performer="Unknown", inputs=[isatools.model.Source(name='GRP2_SBJ3', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Sample(name='GRP2_SBJ3_SINGLE-TREATMENT-FIRST_SMP-whole-organism-1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='whole organism', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='Sequence Order', factor_type=isatools.model.OntologyAnnotation(term='sequence order', term_source=None, term_accession='', comments=[]), comments=[]), value=0, unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit=isatools.model.OntologyAnnotation(term='kg/m^3', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='cadmium chloride', term_source=None, term_accession='', comments=[]), unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=100.0, unit=isatools.model.OntologyAnnotation(term='s', term_source=None, term_accession='', comments=[]))], derives_from=[isatools.model.Source(name='GRP2_SBJ3', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[isatools.model.Comment(name='study step with treatment', value='YES')])]), isatools.model.Process(id="". name="None", executes_protocol=Protocol(
#     name=sample collection
#     protocol_type=sample_collection
#     uri=
#     version=
#     parameters=2 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="2021-12-04", performer="Unknown", inputs=[isatools.model.Source(name='GRP3_SBJ1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Sample(name='GRP3_SBJ1_SINGLE-TREATMENT-THIRD_SMP-whole-organism-1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='whole organism', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='Sequence Order', factor_type=isatools.model.OntologyAnnotation(term='sequence order', term_source=None, term_accession='', comments=[]), comments=[]), value=0, unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit=isatools.model.OntologyAnnotation(term='kg/m^3', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=50.0, unit=isatools.model.OntologyAnnotation(term='s', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='ethoprophos', term_source=None, term_accession='', comments=[]), unit=None)], derives_from=[isatools.model.Source(name='GRP3_SBJ1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[isatools.model.Comment(name='study step with treatment', value='YES')])]), isatools.model.Process(id="". name="None", executes_protocol=Protocol(
#     name=sample collection
#     protocol_type=sample_collection
#     uri=
#     version=
#     parameters=2 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="2021-12-04", performer="Unknown", inputs=[isatools.model.Source(name='GRP3_SBJ3', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Sample(name='GRP3_SBJ3_SINGLE-TREATMENT-THIRD_SMP-whole-organism-1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='whole organism', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='Sequence Order', factor_type=isatools.model.OntologyAnnotation(term='sequence order', term_source=None, term_accession='', comments=[]), comments=[]), value=0, unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit=isatools.model.OntologyAnnotation(term='kg/m^3', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=50.0, unit=isatools.model.OntologyAnnotation(term='s', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='ethoprophos', term_source=None, term_accession='', comments=[]), unit=None)], derives_from=[isatools.model.Source(name='GRP3_SBJ3', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[isatools.model.Comment(name='study step with treatment', value='YES')])]), isatools.model.Process(id="". name="None", executes_protocol=Protocol(
#     name=sample collection
#     protocol_type=sample_collection
#     uri=
#     version=
#     parameters=2 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="2021-12-04", performer="Unknown", inputs=[isatools.model.Source(name='GRP3_SBJ2', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], outputs=[isatools.model.Sample(name='GRP3_SBJ2_SINGLE-TREATMENT-THIRD_SMP-whole-organism-1', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='whole organism', term_source=None, term_accession='', comments=[]), unit=None, comments=[])], factor_values=[isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='Sequence Order', factor_type=isatools.model.OntologyAnnotation(term='sequence order', term_source=None, term_accession='', comments=[]), comments=[]), value=0, unit=None), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='INTENSITY', factor_type=isatools.model.OntologyAnnotation(term='intensity', term_source=None, term_accession='', comments=[]), comments=[]), value=5, unit=isatools.model.OntologyAnnotation(term='kg/m^3', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='DURATION', factor_type=isatools.model.OntologyAnnotation(term='time', term_source=None, term_accession='', comments=[]), comments=[]), value=50.0, unit=isatools.model.OntologyAnnotation(term='s', term_source=None, term_accession='', comments=[])), isatools.model.FactorValue(factor_name=isatools.model.StudyFactor(name='AGENT', factor_type=isatools.model.OntologyAnnotation(term='perturbation agent', term_source=None, term_accession='', comments=[]), comments=[]), value=isatools.model.OntologyAnnotation(term='ethoprophos', term_source=None, term_accession='', comments=[]), unit=None)], derives_from=[isatools.model.Source(name='GRP3_SBJ2', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Study Subject', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C41189', comments=[]), value=isatools.model.OntologyAnnotation(term='Human', term_source=isatools.model.OntologySource(name='NCIT', file='http://purl.obolibrary.org/obo/ncit/releases/2019-03-02/ncit.owl', version='19.02d', description='NCI Thesaurus OBO Edition', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C14225', comments=[]), unit=None, comments=[])], comments=[])], comments=[isatools.model.Comment(name='study step with treatment', value='YES')])])], other_material=[], characteristic_categories=[], comments=[], units=[])], comments=[])

# %% [markdown]
# ### 8. Performing syntactic validation by invoking ISA Validator

# %%
with open(os.path.join(final_dir,'i_investigation.txt')) as isa:
    validation_report=isatab.validate(isa)
# Out:
# 2021-12-04 10:36:13,541 [INFO]: isatab.py(validate:4216) >> Loading... /Users/philippe/Documents/git/isa-api2/isa-api/isa-cookbook/content/notebooks/notebook-output/sd-test/i_investigation.txt
# 2021-12-04 10:36:13,687 [INFO]: isatab.py(validate:4218) >> Running prechecks...
# 2021-12-04 10:36:14,248 [INFO]: isatab.py(validate:4239) >> Finished prechecks...
# 2021-12-04 10:36:14,249 [INFO]: isatab.py(validate:4240) >> Loading configurations found in /Users/philippe/.pyenv/versions/3.9.0/envs/isa-api-py39/src/isatools/isatools/resources/config/xml
# 2021-12-04 10:36:14,313 [INFO]: isatab.py(validate:4245) >> Using configurations found in /Users/philippe/.pyenv/versions/3.9.0/envs/isa-api-py39/src/isatools/isatools/resources/config/xml
# 2021-12-04 10:36:14,314 [INFO]: isatab.py(validate:4247) >> Checking investigation file against configuration...
# 2021-12-04 10:36:14,315 [WARNING]: isatab.py(check_section_against_required_fields_one_value:3373) >> (W) A property value in Study Description of investigation file at column 1 is required
# 2021-12-04 10:36:14,316 [INFO]: isatab.py(validate:4250) >> Finished checking investigation file
# 2021-12-04 10:36:14,317 [INFO]: isatab.py(validate:4269) >> Loading... s_study_01.txt
# 2021-12-04 10:36:14,322 [INFO]: isatab.py(validate:4275) >> Validating s_study_01.txt against default study table configuration
# 2021-12-04 10:36:14,322 [INFO]: isatab.py(validate:4277) >> Checking Factor Value presence...
# 2021-12-04 10:36:14,328 [INFO]: isatab.py(validate:4280) >> Checking required fields...
# 2021-12-04 10:36:14,330 [INFO]: isatab.py(validate:4283) >> Checking generic fields...
# 2021-12-04 10:36:14,334 [INFO]: isatab.py(validate:4291) >> Checking unit fields...
# 2021-12-04 10:36:14,335 [INFO]: isatab.py(validate:4298) >> Checking protocol fields...
# 2021-12-04 10:36:14,336 [WARNING]: isatab.py(check_protocol_fields:4028) >> (W) Protocol(s) of type ['sample collection'] defined in the ISA-configuration expected as a between 'Source Name' and 'Sample Name' but has not been found, in the file 's_study_01.txt'
# 2021-12-04 10:36:14,337 [WARNING]: isatab.py(validate:4303) >> (W) There are some protocol inconsistencies in s_study_01.txt against Study Sample configuration
# 2021-12-04 10:36:14,338 [INFO]: isatab.py(validate:4308) >> Checking ontology fields...
# 2021-12-04 10:36:14,339 [INFO]: isatab.py(validate:4318) >> Checking study group size...
# 2021-12-04 10:36:14,343 [INFO]: isatab.py(validate:4322) >> Finished validation on s_study_01.txt
# 2021-12-04 10:36:14,352 [INFO]: isatab.py(validate:4359) >> Loading... a_AT0_transcription-profiling_nucleotide-sequencing.txt
# 2021-12-04 10:36:14,358 [INFO]: isatab.py(validate:4367) >> Validating a_AT0_transcription-profiling_nucleotide-sequencing.txt against assay table configuration (transcription profiling, nucleotide sequencing)...
# 2021-12-04 10:36:14,358 [INFO]: isatab.py(validate:4373) >> Checking Factor Value presence...
# 2021-12-04 10:36:14,359 [INFO]: isatab.py(validate:4377) >> Checking required fields...
# 2021-12-04 10:36:14,359 [WARNING]: isatab.py(check_required_fields:3697) >> (W) Required field 'Parameter Value[library layout]' not found in the file 'a_AT0_transcription-profiling_nucleotide-sequencing.txt'
# 2021-12-04 10:36:14,360 [WARNING]: isatab.py(check_required_fields:3697) >> (W) Required field 'Assay Name' not found in the file 'a_AT0_transcription-profiling_nucleotide-sequencing.txt'
# 2021-12-04 10:36:14,360 [INFO]: isatab.py(validate:4380) >> Checking generic fields...
# 2021-12-04 10:36:14,363 [INFO]: isatab.py(validate:4391) >> Checking unit fields...
# 2021-12-04 10:36:14,364 [INFO]: isatab.py(validate:4401) >> Checking protocol fields...
# 2021-12-04 10:36:14,366 [WARNING]: isatab.py(check_protocol_fields:4028) >> (W) Protocol(s) of type ['nucleic acid extraction'] defined in the ISA-configuration expected as a between 'Sample Name' and 'Extract Name' but has not been found, in the file 'a_AT0_transcription-profiling_nucleotide-sequencing.txt'
# 2021-12-04 10:36:14,369 [WARNING]: isatab.py(check_protocol_fields:4028) >> (W) Protocol(s) of type ['library construction', 'nucleic acid sequencing'] defined in the ISA-configuration expected as a between 'Extract Name' and 'Raw Data File' but has not been found, in the file 'a_AT0_transcription-profiling_nucleotide-sequencing.txt'
# 2021-12-04 10:36:14,371 [WARNING]: isatab.py(validate:4406) >> (W) There are some protocol inconsistencies in a_AT0_transcription-profiling_nucleotide-sequencing.txt against ('transcription profiling', 'nucleotide sequencing') configuration
# 2021-12-04 10:36:14,372 [INFO]: isatab.py(validate:4413) >> Checking ontology fields...
# 2021-12-04 10:36:14,372 [INFO]: isatab.py(validate:4426) >> Checking study group size...
# 2021-12-04 10:36:14,374 [INFO]: isatab.py(validate:4430) >> Finished validation on a_AT0_transcription-profiling_nucleotide-sequencing.txt
# 2021-12-04 10:36:14,394 [INFO]: isatab.py(validate:4436) >> Checking consistencies between study sample table and assay tables...
# 2021-12-04 10:36:14,395 [INFO]: isatab.py(validate:4441) >> Finished checking study sample table against assay tables...
# 2021-12-04 10:36:14,395 [INFO]: isatab.py(validate:4359) >> Loading... a_AT0_metabolite-profiling_mass-spectrometry.txt
# 2021-12-04 10:36:14,402 [INFO]: isatab.py(validate:4367) >> Validating a_AT0_metabolite-profiling_mass-spectrometry.txt against assay table configuration (metabolite profiling, mass spectrometry)...
# 2021-12-04 10:36:14,403 [INFO]: isatab.py(validate:4373) >> Checking Factor Value presence...
# 2021-12-04 10:36:14,404 [INFO]: isatab.py(validate:4377) >> Checking required fields...
# 2021-12-04 10:36:14,405 [WARNING]: isatab.py(check_required_fields:3697) >> (W) Required field 'MS Assay Name' not found in the file 'a_AT0_metabolite-profiling_mass-spectrometry.txt'
# 2021-12-04 10:36:14,406 [INFO]: isatab.py(validate:4380) >> Checking generic fields...
# 2021-12-04 10:36:14,426 [INFO]: isatab.py(validate:4391) >> Checking unit fields...
# 2021-12-04 10:36:14,427 [INFO]: isatab.py(validate:4401) >> Checking protocol fields...
# 2021-12-04 10:36:14,428 [WARNING]: isatab.py(check_protocol_fields:4028) >> (W) Protocol(s) of type ['extraction'] defined in the ISA-configuration expected as a between 'Sample Name' and 'Extract Name' but has not been found, in the file 'a_AT0_metabolite-profiling_mass-spectrometry.txt'
# 2021-12-04 10:36:14,429 [WARNING]: isatab.py(check_protocol_fields:4028) >> (W) Protocol(s) of type ['labeling'] defined in the ISA-configuration expected as a between 'Extract Name' and 'Labeled Extract Name' but has not been found, in the file 'a_AT0_metabolite-profiling_mass-spectrometry.txt'
# 2021-12-04 10:36:14,429 [WARNING]: isatab.py(check_protocol_fields:4028) >> (W) Protocol(s) of type ['mass spectrometry'] defined in the ISA-configuration expected as a between 'Labeled Extract Name' and 'Raw Spectral Data File' but has not been found, in the file 'a_AT0_metabolite-profiling_mass-spectrometry.txt'
# 2021-12-04 10:36:14,430 [WARNING]: isatab.py(validate:4406) >> (W) There are some protocol inconsistencies in a_AT0_metabolite-profiling_mass-spectrometry.txt against ('metabolite profiling', 'mass spectrometry') configuration
# 2021-12-04 10:36:14,430 [INFO]: isatab.py(validate:4413) >> Checking ontology fields...
# 2021-12-04 10:36:14,431 [WARNING]: isatab.py(check_ontology_fields:4115) >> (W) The Field 'Parameter Value[instrument]' should have values from ontologies and has no ontology headers instead
# 2021-12-04 10:36:14,432 [WARNING]: isatab.py(validate:4418) >> (W) There are some ontology annotation inconsistencies in a_AT0_metabolite-profiling_mass-spectrometry.txt against ('metabolite profiling', 'mass spectrometry') configuration
# 2021-12-04 10:36:14,433 [INFO]: isatab.py(validate:4426) >> Checking study group size...
# 2021-12-04 10:36:14,434 [INFO]: isatab.py(validate:4430) >> Finished validation on a_AT0_metabolite-profiling_mass-spectrometry.txt
# 2021-12-04 10:36:14,437 [INFO]: isatab.py(validate:4436) >> Checking consistencies between study sample table and assay tables...
# 2021-12-04 10:36:14,438 [INFO]: isatab.py(validate:4441) >> Finished checking study sample table against assay tables...
# 2021-12-04 10:36:15,174 [INFO]: utils.py(detect_isatab_process_pooling:76) >> Checking s_study_01.txt
# 2021-12-04 10:36:15,176 [INFO]: utils.py(detect_isatab_process_pooling:85) >> Checking a_AT0_transcription-profiling_nucleotide-sequencing.txt
# 2021-12-04 10:36:15,178 [INFO]: utils.py(detect_isatab_process_pooling:85) >> Checking a_AT0_metabolite-profiling_mass-spectrometry.txt
# 2021-12-04 10:36:15,179 [INFO]: utils.py(detect_graph_process_pooling:57) >> Possible process pooling detected on:  assay0 - derivatization
# 2021-12-04 10:36:15,180 [INFO]: utils.py(detect_graph_process_pooling:57) >> Possible process pooling detected on:  assay0 - derivatization
# 2021-12-04 10:36:15,181 [INFO]: utils.py(detect_graph_process_pooling:57) >> Possible process pooling detected on:  assay0 - derivatization
# 2021-12-04 10:36:15,182 [INFO]: isatab.py(validate:4454) >> Finished validation...

# %%
validation_report["errors"]
# Out:
# []

# %% [markdown]
# ## Conclusion:
#
# With this notebook, we have shown how to use study design information to generate a populated instance of ISA Study object and write it to file.

# %% [markdown]
# ## About this notebook
#
# - authors: philippe.rocca-serra@oerc.ox.ac.uk, massimiliano.izzo@oerc.ox.ac.uk
# - license: CC-BY 4.0
# - support: isatools@googlegroups.com
# - issue tracker: https://github.com/ISA-tools/isa-api/issues
