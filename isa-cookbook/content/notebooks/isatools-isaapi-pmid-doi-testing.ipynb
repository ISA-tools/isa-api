# %%
import isatools

# %%
from isatools.isatab import validate
from isatools.isatab.defaults import _RX_DOI, _RX_PMCID, _RX_PMID, log
from re import compile

# %%
short_doi = "10.1371/journal.pone.0003042"
long_doi = "https://doi.org/10.1371/journal.pone.0003042"

# %%
if _RX_DOI.match(short_doi):
    spl = "Found: {} in DOI field".format(short_doi)
    print(spl)

# %%
if _RX_DOI.match(long_doi):
    spl = "Found: {} in DOI field".format(long_doi)
    print(spl)

# %%
print(_RX_DOI)

# %%
short_pmid = "30003042"
long_pmid = "https://pubmed.ncbi.nlm.nih.gov/30003042"

# %%
if _RX_PMID.match(short_pmid):
    spl = "Found: {} in PMID field".format(short_pmid)
    print(spl)

# %%
if _RX_PMID.match(long_pmid):
    spl = "Found: {} in PMID field".format(long_pmid)
    print(spl)

# %%
print(_RX_PMID)
